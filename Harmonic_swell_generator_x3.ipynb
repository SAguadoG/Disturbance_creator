# %% [markdown]
# ## Harmonic Swell Generator (x3)

# %% [markdown]
# Cargamos las librerías que necesitaremos.

# %%
import os
import numpy as np
import matplotlib.pyplot as plt

# %%
# Obtener el directorio actual del script
directorio_actual = os.path.dirname(os.path.abspath('disturbance_creator'))
directorio_destino = os.path.join(directorio_actual, 'Harmonic_swell_signals')

# Crear los directorios una vez antes de iniciar el bucle

os.makedirs(os.path.join(directorio_destino, 'test'), exist_ok=True)
os.makedirs(os.path.join(directorio_destino, 'train'), exist_ok=True)
os.makedirs(os.path.join(directorio_destino, 'val'), exist_ok=True)


def harmonic_swell_generator():
    
    total_signals = 3600
    num_iterations = 3  # Triplicar las señales
    signals_per_iteration = total_signals
    total_generated = num_iterations * signals_per_iteration
    
    for iteration in range(3):
        for i in range(3601):
            nombre_archivo = f"or_s_{i}.npy"
            ruta_archivo = os.path.join(directorio_actual, 'original_signal', nombre_archivo)

            if os.path.exists(ruta_archivo):
                print(f"Se encontró el archivo {nombre_archivo}")
                # Cargar los datos desde el archivo .npy
                data = np.load(ruta_archivo)
                # Normalizar la señal RMS
                signal_original = data / np.sqrt(np.mean(data**2))

                # Parámetros del armónico
                # Generar un vector de tiempo (tasa de muestreo de 10,000Hz)
                tiempo = np.arange(len(signal_original)) / 10000
                num_harmonics = np.random.randint(1, 3)  # Generar un número aleatorio de armónicos (de 1 a 2)
                harmonic_amplitude = 0.1  # Amplitud del armónico

                # Generar la señal armónica sumando múltiples armónicos a la señal original
                harmonic_signal = np.zeros_like(signal_original)
                for _ in range(num_harmonics):
                    harmonic_freq = np.random.randint(1, 11) * 50  # Generar un armónico aleatorio entre 50 Hz y 500 Hz
                    harmonic_signal += harmonic_amplitude * np.sin(2 * np.pi * harmonic_freq * tiempo)

                # Parámetros del Swell
                longitud_signal = len(signal_original)
                duracion_amplificacion = np.random.randint(3000, 5000)  # 0.3 a 0.5 segundos aleatoriamente
                factor_amplitud_min = 1.2
                factor_amplitud_max = 1.7

                # Generar la posición aleatoria para la amplificación
                inicio_amplificacion = np.random.randint(0, longitud_signal - duracion_amplificacion)

                # Generar el factor de amplificación aleatorio
                factor_amplitud = np.random.uniform(factor_amplitud_min, factor_amplitud_max)

                # Aplicar la amplificación en la parte aleatoria de la señal original
                signal_sag = np.copy(signal_original)
                signal_sag[inicio_amplificacion:(inicio_amplificacion + duracion_amplificacion)] *= factor_amplitud

                # Sumar la señal armónica y la señal con swell
                signal_with_harmonic = signal_original + harmonic_signal
                signal_with_harmonic_and_swell = np.copy(signal_with_harmonic)
                signal_with_harmonic_and_swell[inicio_amplificacion:(inicio_amplificacion + duracion_amplificacion)] *= (factor_amplitud)

                # Determinar la carpeta de destino
                index_global = iteration * signals_per_iteration + i
                if index_global < 7561:
                    directorio_destino_final = os.path.join(directorio_destino, 'train')
                elif index_global < 9181:
                    directorio_destino_final = os.path.join(directorio_destino, 'test')
                else:
                    directorio_destino_final = os.path.join(directorio_destino, 'val')
                #print('Index global:', index_global)

                nombre_archivo_nuevo = f"hrc_sw_s_{index_global}.npy"
                ruta_archivo_nuevo = os.path.join(directorio_destino_final, nombre_archivo_nuevo)
                np.save(ruta_archivo_nuevo, signal_with_harmonic_and_swell)
                print(f"Señal con armónico y Swell guardada en {nombre_archivo_nuevo}")

            else:
                print("archivo no encontrado")


harmonic_swell_generator()
# Out:
# archivo no encontrado
# Se encontró el archivo or_s_1.npy
# Señal con armónico y Swell guardada en hrc_sw_s_1.npy
# Se encontró el archivo or_s_2.npy
# Señal con armónico y Swell guardada en hrc_sw_s_2.npy
# Se encontró el archivo or_s_3.npy
# Señal con armónico y Swell guardada en hrc_sw_s_3.npy
# Se encontró el archivo or_s_4.npy
# Señal con armónico y Swell guardada en hrc_sw_s_4.npy
# Se encontró el archivo or_s_5.npy
# Señal con armónico y Swell guardada en hrc_sw_s_5.npy
# Se encontró el archivo or_s_6.npy
# Señal con armónico y Swell guardada en hrc_sw_s_6.npy
# Se encontró el archivo or_s_7.npy
# Señal con armónico y Swell guardada en hrc_sw_s_7.npy
# Se encontró el archivo or_s_8.npy
# Señal con armónico y Swell guardada en hrc_sw_s_8.npy
# Se encontró el archivo or_s_9.npy
# Señal con armónico y Swell guardada en hrc_sw_s_9.npy
# Se encontró el archivo or_s_10.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10.npy
# Se encontró el archivo or_s_11.npy
# Señal con armónico y Swell guardada en hrc_sw_s_11.npy
# Se encontró el archivo or_s_12.npy
# Señal con armónico y Swell guardada en hrc_sw_s_12.npy
# Se encontró el archivo or_s_13.npy
# Señal con armónico y Swell guardada en hrc_sw_s_13.npy
# Se encontró el archivo or_s_14.npy
# Señal con armónico y Swell guardada en hrc_sw_s_14.npy
# Se encontró el archivo or_s_15.npy
# Señal con armónico y Swell guardada en hrc_sw_s_15.npy
# Se encontró el archivo or_s_16.npy
# Señal con armónico y Swell guardada en hrc_sw_s_16.npy
# Se encontró el archivo or_s_17.npy
# Señal con armónico y Swell guardada en hrc_sw_s_17.npy
# Se encontró el archivo or_s_18.npy
# Señal con armónico y Swell guardada en hrc_sw_s_18.npy
# Se encontró el archivo or_s_19.npy
# Señal con armónico y Swell guardada en hrc_sw_s_19.npy
# Se encontró el archivo or_s_20.npy
# Señal con armónico y Swell guardada en hrc_sw_s_20.npy
# Se encontró el archivo or_s_21.npy
# Señal con armónico y Swell guardada en hrc_sw_s_21.npy
# Se encontró el archivo or_s_22.npy
# Señal con armónico y Swell guardada en hrc_sw_s_22.npy
# Se encontró el archivo or_s_23.npy
# Señal con armónico y Swell guardada en hrc_sw_s_23.npy
# Se encontró el archivo or_s_24.npy
# Señal con armónico y Swell guardada en hrc_sw_s_24.npy
# Se encontró el archivo or_s_25.npy
# Señal con armónico y Swell guardada en hrc_sw_s_25.npy
# Se encontró el archivo or_s_26.npy
# Señal con armónico y Swell guardada en hrc_sw_s_26.npy
# Se encontró el archivo or_s_27.npy
# Señal con armónico y Swell guardada en hrc_sw_s_27.npy
# Se encontró el archivo or_s_28.npy
# Señal con armónico y Swell guardada en hrc_sw_s_28.npy
# Se encontró el archivo or_s_29.npy
# Señal con armónico y Swell guardada en hrc_sw_s_29.npy
# Se encontró el archivo or_s_30.npy
# Señal con armónico y Swell guardada en hrc_sw_s_30.npy
# Se encontró el archivo or_s_31.npy
# Señal con armónico y Swell guardada en hrc_sw_s_31.npy
# Se encontró el archivo or_s_32.npy
# Señal con armónico y Swell guardada en hrc_sw_s_32.npy
# Se encontró el archivo or_s_33.npy
# Señal con armónico y Swell guardada en hrc_sw_s_33.npy
# Se encontró el archivo or_s_34.npy
# Señal con armónico y Swell guardada en hrc_sw_s_34.npy
# Se encontró el archivo or_s_35.npy
# Señal con armónico y Swell guardada en hrc_sw_s_35.npy
# Se encontró el archivo or_s_36.npy
# Señal con armónico y Swell guardada en hrc_sw_s_36.npy
# Se encontró el archivo or_s_37.npy
# Señal con armónico y Swell guardada en hrc_sw_s_37.npy
# Se encontró el archivo or_s_38.npy
# Señal con armónico y Swell guardada en hrc_sw_s_38.npy
# Se encontró el archivo or_s_39.npy
# Señal con armónico y Swell guardada en hrc_sw_s_39.npy
# Se encontró el archivo or_s_40.npy
# Señal con armónico y Swell guardada en hrc_sw_s_40.npy
# Se encontró el archivo or_s_41.npy
# Señal con armónico y Swell guardada en hrc_sw_s_41.npy
# Se encontró el archivo or_s_42.npy
# Señal con armónico y Swell guardada en hrc_sw_s_42.npy
# Se encontró el archivo or_s_43.npy
# Señal con armónico y Swell guardada en hrc_sw_s_43.npy
# Se encontró el archivo or_s_44.npy
# Señal con armónico y Swell guardada en hrc_sw_s_44.npy
# Se encontró el archivo or_s_45.npy
# Señal con armónico y Swell guardada en hrc_sw_s_45.npy
# Se encontró el archivo or_s_46.npy
# Señal con armónico y Swell guardada en hrc_sw_s_46.npy
# Se encontró el archivo or_s_47.npy
# Señal con armónico y Swell guardada en hrc_sw_s_47.npy
# Se encontró el archivo or_s_48.npy
# Señal con armónico y Swell guardada en hrc_sw_s_48.npy
# Se encontró el archivo or_s_49.npy
# Señal con armónico y Swell guardada en hrc_sw_s_49.npy
# Se encontró el archivo or_s_50.npy
# Señal con armónico y Swell guardada en hrc_sw_s_50.npy
# Se encontró el archivo or_s_51.npy
# Señal con armónico y Swell guardada en hrc_sw_s_51.npy
# Se encontró el archivo or_s_52.npy
# Señal con armónico y Swell guardada en hrc_sw_s_52.npy
# Se encontró el archivo or_s_53.npy
# Señal con armónico y Swell guardada en hrc_sw_s_53.npy
# Se encontró el archivo or_s_54.npy
# Señal con armónico y Swell guardada en hrc_sw_s_54.npy
# Se encontró el archivo or_s_55.npy
# Señal con armónico y Swell guardada en hrc_sw_s_55.npy
# Se encontró el archivo or_s_56.npy
# Señal con armónico y Swell guardada en hrc_sw_s_56.npy
# Se encontró el archivo or_s_57.npy
# Señal con armónico y Swell guardada en hrc_sw_s_57.npy
# Se encontró el archivo or_s_58.npy
# Señal con armónico y Swell guardada en hrc_sw_s_58.npy
# Se encontró el archivo or_s_59.npy
# Señal con armónico y Swell guardada en hrc_sw_s_59.npy
# Se encontró el archivo or_s_60.npy
# Señal con armónico y Swell guardada en hrc_sw_s_60.npy
# Se encontró el archivo or_s_61.npy
# Señal con armónico y Swell guardada en hrc_sw_s_61.npy
# Se encontró el archivo or_s_62.npy
# Señal con armónico y Swell guardada en hrc_sw_s_62.npy
# Se encontró el archivo or_s_63.npy
# Señal con armónico y Swell guardada en hrc_sw_s_63.npy
# Se encontró el archivo or_s_64.npy
# Señal con armónico y Swell guardada en hrc_sw_s_64.npy
# Se encontró el archivo or_s_65.npy
# Señal con armónico y Swell guardada en hrc_sw_s_65.npy
# Se encontró el archivo or_s_66.npy
# Señal con armónico y Swell guardada en hrc_sw_s_66.npy
# Se encontró el archivo or_s_67.npy
# Señal con armónico y Swell guardada en hrc_sw_s_67.npy
# Se encontró el archivo or_s_68.npy
# Señal con armónico y Swell guardada en hrc_sw_s_68.npy
# Se encontró el archivo or_s_69.npy
# Señal con armónico y Swell guardada en hrc_sw_s_69.npy
# Se encontró el archivo or_s_70.npy
# Señal con armónico y Swell guardada en hrc_sw_s_70.npy
# Se encontró el archivo or_s_71.npy
# Señal con armónico y Swell guardada en hrc_sw_s_71.npy
# Se encontró el archivo or_s_72.npy
# Señal con armónico y Swell guardada en hrc_sw_s_72.npy
# Se encontró el archivo or_s_73.npy
# Señal con armónico y Swell guardada en hrc_sw_s_73.npy
# Se encontró el archivo or_s_74.npy
# Señal con armónico y Swell guardada en hrc_sw_s_74.npy
# Se encontró el archivo or_s_75.npy
# Señal con armónico y Swell guardada en hrc_sw_s_75.npy
# Se encontró el archivo or_s_76.npy
# Señal con armónico y Swell guardada en hrc_sw_s_76.npy
# Se encontró el archivo or_s_77.npy
# Señal con armónico y Swell guardada en hrc_sw_s_77.npy
# Se encontró el archivo or_s_78.npy
# Señal con armónico y Swell guardada en hrc_sw_s_78.npy
# Se encontró el archivo or_s_79.npy
# Señal con armónico y Swell guardada en hrc_sw_s_79.npy
# Se encontró el archivo or_s_80.npy
# Señal con armónico y Swell guardada en hrc_sw_s_80.npy
# Se encontró el archivo or_s_81.npy
# Señal con armónico y Swell guardada en hrc_sw_s_81.npy
# Se encontró el archivo or_s_82.npy
# Señal con armónico y Swell guardada en hrc_sw_s_82.npy
# Se encontró el archivo or_s_83.npy
# Señal con armónico y Swell guardada en hrc_sw_s_83.npy
# Se encontró el archivo or_s_84.npy
# Señal con armónico y Swell guardada en hrc_sw_s_84.npy
# Se encontró el archivo or_s_85.npy
# Señal con armónico y Swell guardada en hrc_sw_s_85.npy
# Se encontró el archivo or_s_86.npy
# Señal con armónico y Swell guardada en hrc_sw_s_86.npy
# Se encontró el archivo or_s_87.npy
# Señal con armónico y Swell guardada en hrc_sw_s_87.npy
# Se encontró el archivo or_s_88.npy
# Señal con armónico y Swell guardada en hrc_sw_s_88.npy
# Se encontró el archivo or_s_89.npy
# Señal con armónico y Swell guardada en hrc_sw_s_89.npy
# Se encontró el archivo or_s_90.npy
# Señal con armónico y Swell guardada en hrc_sw_s_90.npy
# Se encontró el archivo or_s_91.npy
# Señal con armónico y Swell guardada en hrc_sw_s_91.npy
# Se encontró el archivo or_s_92.npy
# Señal con armónico y Swell guardada en hrc_sw_s_92.npy
# Se encontró el archivo or_s_93.npy
# Señal con armónico y Swell guardada en hrc_sw_s_93.npy
# Se encontró el archivo or_s_94.npy
# Señal con armónico y Swell guardada en hrc_sw_s_94.npy
# Se encontró el archivo or_s_95.npy
# Señal con armónico y Swell guardada en hrc_sw_s_95.npy
# Se encontró el archivo or_s_96.npy
# Señal con armónico y Swell guardada en hrc_sw_s_96.npy
# Se encontró el archivo or_s_97.npy
# Señal con armónico y Swell guardada en hrc_sw_s_97.npy
# Se encontró el archivo or_s_98.npy
# Señal con armónico y Swell guardada en hrc_sw_s_98.npy
# Se encontró el archivo or_s_99.npy
# Señal con armónico y Swell guardada en hrc_sw_s_99.npy
# Se encontró el archivo or_s_100.npy
# Señal con armónico y Swell guardada en hrc_sw_s_100.npy
# Se encontró el archivo or_s_101.npy
# Señal con armónico y Swell guardada en hrc_sw_s_101.npy
# Se encontró el archivo or_s_102.npy
# Señal con armónico y Swell guardada en hrc_sw_s_102.npy
# Se encontró el archivo or_s_103.npy
# Señal con armónico y Swell guardada en hrc_sw_s_103.npy
# Se encontró el archivo or_s_104.npy
# Señal con armónico y Swell guardada en hrc_sw_s_104.npy
# Se encontró el archivo or_s_105.npy
# Señal con armónico y Swell guardada en hrc_sw_s_105.npy
# Se encontró el archivo or_s_106.npy
# Señal con armónico y Swell guardada en hrc_sw_s_106.npy
# Se encontró el archivo or_s_107.npy
# Señal con armónico y Swell guardada en hrc_sw_s_107.npy
# Se encontró el archivo or_s_108.npy
# Señal con armónico y Swell guardada en hrc_sw_s_108.npy
# Se encontró el archivo or_s_109.npy
# Señal con armónico y Swell guardada en hrc_sw_s_109.npy
# Se encontró el archivo or_s_110.npy
# Señal con armónico y Swell guardada en hrc_sw_s_110.npy
# Se encontró el archivo or_s_111.npy
# Señal con armónico y Swell guardada en hrc_sw_s_111.npy
# Se encontró el archivo or_s_112.npy
# Señal con armónico y Swell guardada en hrc_sw_s_112.npy
# Se encontró el archivo or_s_113.npy
# Señal con armónico y Swell guardada en hrc_sw_s_113.npy
# Se encontró el archivo or_s_114.npy
# Señal con armónico y Swell guardada en hrc_sw_s_114.npy
# Se encontró el archivo or_s_115.npy
# Señal con armónico y Swell guardada en hrc_sw_s_115.npy
# Se encontró el archivo or_s_116.npy
# Señal con armónico y Swell guardada en hrc_sw_s_116.npy
# Se encontró el archivo or_s_117.npy
# Señal con armónico y Swell guardada en hrc_sw_s_117.npy
# Se encontró el archivo or_s_118.npy
# Señal con armónico y Swell guardada en hrc_sw_s_118.npy
# Se encontró el archivo or_s_119.npy
# Señal con armónico y Swell guardada en hrc_sw_s_119.npy
# Se encontró el archivo or_s_120.npy
# Señal con armónico y Swell guardada en hrc_sw_s_120.npy
# Se encontró el archivo or_s_121.npy
# Señal con armónico y Swell guardada en hrc_sw_s_121.npy
# Se encontró el archivo or_s_122.npy
# Señal con armónico y Swell guardada en hrc_sw_s_122.npy
# Se encontró el archivo or_s_123.npy
# Señal con armónico y Swell guardada en hrc_sw_s_123.npy
# Se encontró el archivo or_s_124.npy
# Señal con armónico y Swell guardada en hrc_sw_s_124.npy
# Se encontró el archivo or_s_125.npy
# Señal con armónico y Swell guardada en hrc_sw_s_125.npy
# Se encontró el archivo or_s_126.npy
# Señal con armónico y Swell guardada en hrc_sw_s_126.npy
# Se encontró el archivo or_s_127.npy
# Señal con armónico y Swell guardada en hrc_sw_s_127.npy
# Se encontró el archivo or_s_128.npy
# Señal con armónico y Swell guardada en hrc_sw_s_128.npy
# Se encontró el archivo or_s_129.npy
# Señal con armónico y Swell guardada en hrc_sw_s_129.npy
# Se encontró el archivo or_s_130.npy
# Señal con armónico y Swell guardada en hrc_sw_s_130.npy
# Se encontró el archivo or_s_131.npy
# Señal con armónico y Swell guardada en hrc_sw_s_131.npy
# Se encontró el archivo or_s_132.npy
# Señal con armónico y Swell guardada en hrc_sw_s_132.npy
# Se encontró el archivo or_s_133.npy
# Señal con armónico y Swell guardada en hrc_sw_s_133.npy
# Se encontró el archivo or_s_134.npy
# Señal con armónico y Swell guardada en hrc_sw_s_134.npy
# Se encontró el archivo or_s_135.npy
# Señal con armónico y Swell guardada en hrc_sw_s_135.npy
# Se encontró el archivo or_s_136.npy
# Señal con armónico y Swell guardada en hrc_sw_s_136.npy
# Se encontró el archivo or_s_137.npy
# Señal con armónico y Swell guardada en hrc_sw_s_137.npy
# Se encontró el archivo or_s_138.npy
# Señal con armónico y Swell guardada en hrc_sw_s_138.npy
# Se encontró el archivo or_s_139.npy
# Señal con armónico y Swell guardada en hrc_sw_s_139.npy
# Se encontró el archivo or_s_140.npy
# Señal con armónico y Swell guardada en hrc_sw_s_140.npy
# Se encontró el archivo or_s_141.npy
# Señal con armónico y Swell guardada en hrc_sw_s_141.npy
# Se encontró el archivo or_s_142.npy
# Señal con armónico y Swell guardada en hrc_sw_s_142.npy
# Se encontró el archivo or_s_143.npy
# Señal con armónico y Swell guardada en hrc_sw_s_143.npy
# Se encontró el archivo or_s_144.npy
# Señal con armónico y Swell guardada en hrc_sw_s_144.npy
# Se encontró el archivo or_s_145.npy
# Señal con armónico y Swell guardada en hrc_sw_s_145.npy
# Se encontró el archivo or_s_146.npy
# Señal con armónico y Swell guardada en hrc_sw_s_146.npy
# Se encontró el archivo or_s_147.npy
# Señal con armónico y Swell guardada en hrc_sw_s_147.npy
# Se encontró el archivo or_s_148.npy
# Señal con armónico y Swell guardada en hrc_sw_s_148.npy
# Se encontró el archivo or_s_149.npy
# Señal con armónico y Swell guardada en hrc_sw_s_149.npy
# Se encontró el archivo or_s_150.npy
# Señal con armónico y Swell guardada en hrc_sw_s_150.npy
# Se encontró el archivo or_s_151.npy
# Señal con armónico y Swell guardada en hrc_sw_s_151.npy
# Se encontró el archivo or_s_152.npy
# Señal con armónico y Swell guardada en hrc_sw_s_152.npy
# Se encontró el archivo or_s_153.npy
# Señal con armónico y Swell guardada en hrc_sw_s_153.npy
# Se encontró el archivo or_s_154.npy
# Señal con armónico y Swell guardada en hrc_sw_s_154.npy
# Se encontró el archivo or_s_155.npy
# Señal con armónico y Swell guardada en hrc_sw_s_155.npy
# Se encontró el archivo or_s_156.npy
# Señal con armónico y Swell guardada en hrc_sw_s_156.npy
# Se encontró el archivo or_s_157.npy
# Señal con armónico y Swell guardada en hrc_sw_s_157.npy
# Se encontró el archivo or_s_158.npy
# Señal con armónico y Swell guardada en hrc_sw_s_158.npy
# Se encontró el archivo or_s_159.npy
# Señal con armónico y Swell guardada en hrc_sw_s_159.npy
# Se encontró el archivo or_s_160.npy
# Señal con armónico y Swell guardada en hrc_sw_s_160.npy
# Se encontró el archivo or_s_161.npy
# Señal con armónico y Swell guardada en hrc_sw_s_161.npy
# Se encontró el archivo or_s_162.npy
# Señal con armónico y Swell guardada en hrc_sw_s_162.npy
# Se encontró el archivo or_s_163.npy
# Señal con armónico y Swell guardada en hrc_sw_s_163.npy
# Se encontró el archivo or_s_164.npy
# Señal con armónico y Swell guardada en hrc_sw_s_164.npy
# Se encontró el archivo or_s_165.npy
# Señal con armónico y Swell guardada en hrc_sw_s_165.npy
# Se encontró el archivo or_s_166.npy
# Señal con armónico y Swell guardada en hrc_sw_s_166.npy
# Se encontró el archivo or_s_167.npy
# Señal con armónico y Swell guardada en hrc_sw_s_167.npy
# Se encontró el archivo or_s_168.npy
# Señal con armónico y Swell guardada en hrc_sw_s_168.npy
# Se encontró el archivo or_s_169.npy
# Señal con armónico y Swell guardada en hrc_sw_s_169.npy
# Se encontró el archivo or_s_170.npy
# Señal con armónico y Swell guardada en hrc_sw_s_170.npy
# Se encontró el archivo or_s_171.npy
# Señal con armónico y Swell guardada en hrc_sw_s_171.npy
# Se encontró el archivo or_s_172.npy
# Señal con armónico y Swell guardada en hrc_sw_s_172.npy
# Se encontró el archivo or_s_173.npy
# Señal con armónico y Swell guardada en hrc_sw_s_173.npy
# Se encontró el archivo or_s_174.npy
# Señal con armónico y Swell guardada en hrc_sw_s_174.npy
# Se encontró el archivo or_s_175.npy
# Señal con armónico y Swell guardada en hrc_sw_s_175.npy
# Se encontró el archivo or_s_176.npy
# Señal con armónico y Swell guardada en hrc_sw_s_176.npy
# Se encontró el archivo or_s_177.npy
# Señal con armónico y Swell guardada en hrc_sw_s_177.npy
# Se encontró el archivo or_s_178.npy
# Señal con armónico y Swell guardada en hrc_sw_s_178.npy
# Se encontró el archivo or_s_179.npy
# Señal con armónico y Swell guardada en hrc_sw_s_179.npy
# Se encontró el archivo or_s_180.npy
# Señal con armónico y Swell guardada en hrc_sw_s_180.npy
# Se encontró el archivo or_s_181.npy
# Señal con armónico y Swell guardada en hrc_sw_s_181.npy
# Se encontró el archivo or_s_182.npy
# Señal con armónico y Swell guardada en hrc_sw_s_182.npy
# Se encontró el archivo or_s_183.npy
# Señal con armónico y Swell guardada en hrc_sw_s_183.npy
# Se encontró el archivo or_s_184.npy
# Señal con armónico y Swell guardada en hrc_sw_s_184.npy
# Se encontró el archivo or_s_185.npy
# Señal con armónico y Swell guardada en hrc_sw_s_185.npy
# Se encontró el archivo or_s_186.npy
# Señal con armónico y Swell guardada en hrc_sw_s_186.npy
# Se encontró el archivo or_s_187.npy
# Señal con armónico y Swell guardada en hrc_sw_s_187.npy
# Se encontró el archivo or_s_188.npy
# Señal con armónico y Swell guardada en hrc_sw_s_188.npy
# Se encontró el archivo or_s_189.npy
# Señal con armónico y Swell guardada en hrc_sw_s_189.npy
# Se encontró el archivo or_s_190.npy
# Señal con armónico y Swell guardada en hrc_sw_s_190.npy
# Se encontró el archivo or_s_191.npy
# Señal con armónico y Swell guardada en hrc_sw_s_191.npy
# Se encontró el archivo or_s_192.npy
# Señal con armónico y Swell guardada en hrc_sw_s_192.npy
# Se encontró el archivo or_s_193.npy
# Señal con armónico y Swell guardada en hrc_sw_s_193.npy
# Se encontró el archivo or_s_194.npy
# Señal con armónico y Swell guardada en hrc_sw_s_194.npy
# Se encontró el archivo or_s_195.npy
# Señal con armónico y Swell guardada en hrc_sw_s_195.npy
# Se encontró el archivo or_s_196.npy
# Señal con armónico y Swell guardada en hrc_sw_s_196.npy
# Se encontró el archivo or_s_197.npy
# Señal con armónico y Swell guardada en hrc_sw_s_197.npy
# Se encontró el archivo or_s_198.npy
# Señal con armónico y Swell guardada en hrc_sw_s_198.npy
# Se encontró el archivo or_s_199.npy
# Señal con armónico y Swell guardada en hrc_sw_s_199.npy
# Se encontró el archivo or_s_200.npy
# Señal con armónico y Swell guardada en hrc_sw_s_200.npy
# Se encontró el archivo or_s_201.npy
# Señal con armónico y Swell guardada en hrc_sw_s_201.npy
# Se encontró el archivo or_s_202.npy
# Señal con armónico y Swell guardada en hrc_sw_s_202.npy
# Se encontró el archivo or_s_203.npy
# Señal con armónico y Swell guardada en hrc_sw_s_203.npy
# Se encontró el archivo or_s_204.npy
# Señal con armónico y Swell guardada en hrc_sw_s_204.npy
# Se encontró el archivo or_s_205.npy
# Señal con armónico y Swell guardada en hrc_sw_s_205.npy
# Se encontró el archivo or_s_206.npy
# Señal con armónico y Swell guardada en hrc_sw_s_206.npy
# Se encontró el archivo or_s_207.npy
# Señal con armónico y Swell guardada en hrc_sw_s_207.npy
# Se encontró el archivo or_s_208.npy
# Señal con armónico y Swell guardada en hrc_sw_s_208.npy
# Se encontró el archivo or_s_209.npy
# Señal con armónico y Swell guardada en hrc_sw_s_209.npy
# Se encontró el archivo or_s_210.npy
# Señal con armónico y Swell guardada en hrc_sw_s_210.npy
# Se encontró el archivo or_s_211.npy
# Señal con armónico y Swell guardada en hrc_sw_s_211.npy
# Se encontró el archivo or_s_212.npy
# Señal con armónico y Swell guardada en hrc_sw_s_212.npy
# Se encontró el archivo or_s_213.npy
# Señal con armónico y Swell guardada en hrc_sw_s_213.npy
# Se encontró el archivo or_s_214.npy
# Señal con armónico y Swell guardada en hrc_sw_s_214.npy
# Se encontró el archivo or_s_215.npy
# Señal con armónico y Swell guardada en hrc_sw_s_215.npy
# Se encontró el archivo or_s_216.npy
# Señal con armónico y Swell guardada en hrc_sw_s_216.npy
# Se encontró el archivo or_s_217.npy
# Señal con armónico y Swell guardada en hrc_sw_s_217.npy
# Se encontró el archivo or_s_218.npy
# Señal con armónico y Swell guardada en hrc_sw_s_218.npy
# Se encontró el archivo or_s_219.npy
# Señal con armónico y Swell guardada en hrc_sw_s_219.npy
# Se encontró el archivo or_s_220.npy
# Señal con armónico y Swell guardada en hrc_sw_s_220.npy
# Se encontró el archivo or_s_221.npy
# Señal con armónico y Swell guardada en hrc_sw_s_221.npy
# Se encontró el archivo or_s_222.npy
# Señal con armónico y Swell guardada en hrc_sw_s_222.npy
# Se encontró el archivo or_s_223.npy
# Señal con armónico y Swell guardada en hrc_sw_s_223.npy
# Se encontró el archivo or_s_224.npy
# Señal con armónico y Swell guardada en hrc_sw_s_224.npy
# Se encontró el archivo or_s_225.npy
# Señal con armónico y Swell guardada en hrc_sw_s_225.npy
# Se encontró el archivo or_s_226.npy
# Señal con armónico y Swell guardada en hrc_sw_s_226.npy
# Se encontró el archivo or_s_227.npy
# Señal con armónico y Swell guardada en hrc_sw_s_227.npy
# Se encontró el archivo or_s_228.npy
# Señal con armónico y Swell guardada en hrc_sw_s_228.npy
# Se encontró el archivo or_s_229.npy
# Señal con armónico y Swell guardada en hrc_sw_s_229.npy
# Se encontró el archivo or_s_230.npy
# Señal con armónico y Swell guardada en hrc_sw_s_230.npy
# Se encontró el archivo or_s_231.npy
# Señal con armónico y Swell guardada en hrc_sw_s_231.npy
# Se encontró el archivo or_s_232.npy
# Señal con armónico y Swell guardada en hrc_sw_s_232.npy
# Se encontró el archivo or_s_233.npy
# Señal con armónico y Swell guardada en hrc_sw_s_233.npy
# Se encontró el archivo or_s_234.npy
# Señal con armónico y Swell guardada en hrc_sw_s_234.npy
# Se encontró el archivo or_s_235.npy
# Señal con armónico y Swell guardada en hrc_sw_s_235.npy
# Se encontró el archivo or_s_236.npy
# Señal con armónico y Swell guardada en hrc_sw_s_236.npy
# Se encontró el archivo or_s_237.npy
# Señal con armónico y Swell guardada en hrc_sw_s_237.npy
# Se encontró el archivo or_s_238.npy
# Señal con armónico y Swell guardada en hrc_sw_s_238.npy
# Se encontró el archivo or_s_239.npy
# Señal con armónico y Swell guardada en hrc_sw_s_239.npy
# Se encontró el archivo or_s_240.npy
# Señal con armónico y Swell guardada en hrc_sw_s_240.npy
# Se encontró el archivo or_s_241.npy
# Señal con armónico y Swell guardada en hrc_sw_s_241.npy
# Se encontró el archivo or_s_242.npy
# Señal con armónico y Swell guardada en hrc_sw_s_242.npy
# Se encontró el archivo or_s_243.npy
# Señal con armónico y Swell guardada en hrc_sw_s_243.npy
# Se encontró el archivo or_s_244.npy
# Señal con armónico y Swell guardada en hrc_sw_s_244.npy
# Se encontró el archivo or_s_245.npy
# Señal con armónico y Swell guardada en hrc_sw_s_245.npy
# Se encontró el archivo or_s_246.npy
# Señal con armónico y Swell guardada en hrc_sw_s_246.npy
# Se encontró el archivo or_s_247.npy
# Señal con armónico y Swell guardada en hrc_sw_s_247.npy
# Se encontró el archivo or_s_248.npy
# Señal con armónico y Swell guardada en hrc_sw_s_248.npy
# Se encontró el archivo or_s_249.npy
# Señal con armónico y Swell guardada en hrc_sw_s_249.npy
# Se encontró el archivo or_s_250.npy
# Señal con armónico y Swell guardada en hrc_sw_s_250.npy
# Se encontró el archivo or_s_251.npy
# Señal con armónico y Swell guardada en hrc_sw_s_251.npy
# Se encontró el archivo or_s_252.npy
# Señal con armónico y Swell guardada en hrc_sw_s_252.npy
# Se encontró el archivo or_s_253.npy
# Señal con armónico y Swell guardada en hrc_sw_s_253.npy
# Se encontró el archivo or_s_254.npy
# Señal con armónico y Swell guardada en hrc_sw_s_254.npy
# Se encontró el archivo or_s_255.npy
# Señal con armónico y Swell guardada en hrc_sw_s_255.npy
# Se encontró el archivo or_s_256.npy
# Señal con armónico y Swell guardada en hrc_sw_s_256.npy
# Se encontró el archivo or_s_257.npy
# Señal con armónico y Swell guardada en hrc_sw_s_257.npy
# Se encontró el archivo or_s_258.npy
# Señal con armónico y Swell guardada en hrc_sw_s_258.npy
# Se encontró el archivo or_s_259.npy
# Señal con armónico y Swell guardada en hrc_sw_s_259.npy
# Se encontró el archivo or_s_260.npy
# Señal con armónico y Swell guardada en hrc_sw_s_260.npy
# Se encontró el archivo or_s_261.npy
# Señal con armónico y Swell guardada en hrc_sw_s_261.npy
# Se encontró el archivo or_s_262.npy
# Señal con armónico y Swell guardada en hrc_sw_s_262.npy
# Se encontró el archivo or_s_263.npy
# Señal con armónico y Swell guardada en hrc_sw_s_263.npy
# Se encontró el archivo or_s_264.npy
# Señal con armónico y Swell guardada en hrc_sw_s_264.npy
# Se encontró el archivo or_s_265.npy
# Señal con armónico y Swell guardada en hrc_sw_s_265.npy
# Se encontró el archivo or_s_266.npy
# Señal con armónico y Swell guardada en hrc_sw_s_266.npy
# Se encontró el archivo or_s_267.npy
# Señal con armónico y Swell guardada en hrc_sw_s_267.npy
# Se encontró el archivo or_s_268.npy
# Señal con armónico y Swell guardada en hrc_sw_s_268.npy
# Se encontró el archivo or_s_269.npy
# Señal con armónico y Swell guardada en hrc_sw_s_269.npy
# Se encontró el archivo or_s_270.npy
# Señal con armónico y Swell guardada en hrc_sw_s_270.npy
# Se encontró el archivo or_s_271.npy
# Señal con armónico y Swell guardada en hrc_sw_s_271.npy
# Se encontró el archivo or_s_272.npy
# Señal con armónico y Swell guardada en hrc_sw_s_272.npy
# Se encontró el archivo or_s_273.npy
# Señal con armónico y Swell guardada en hrc_sw_s_273.npy
# Se encontró el archivo or_s_274.npy
# Señal con armónico y Swell guardada en hrc_sw_s_274.npy
# Se encontró el archivo or_s_275.npy
# Señal con armónico y Swell guardada en hrc_sw_s_275.npy
# Se encontró el archivo or_s_276.npy
# Señal con armónico y Swell guardada en hrc_sw_s_276.npy
# Se encontró el archivo or_s_277.npy
# Señal con armónico y Swell guardada en hrc_sw_s_277.npy
# Se encontró el archivo or_s_278.npy
# Señal con armónico y Swell guardada en hrc_sw_s_278.npy
# Se encontró el archivo or_s_279.npy
# Señal con armónico y Swell guardada en hrc_sw_s_279.npy
# Se encontró el archivo or_s_280.npy
# Señal con armónico y Swell guardada en hrc_sw_s_280.npy
# Se encontró el archivo or_s_281.npy
# Señal con armónico y Swell guardada en hrc_sw_s_281.npy
# Se encontró el archivo or_s_282.npy
# Señal con armónico y Swell guardada en hrc_sw_s_282.npy
# Se encontró el archivo or_s_283.npy
# Señal con armónico y Swell guardada en hrc_sw_s_283.npy
# Se encontró el archivo or_s_284.npy
# Señal con armónico y Swell guardada en hrc_sw_s_284.npy
# Se encontró el archivo or_s_285.npy
# Señal con armónico y Swell guardada en hrc_sw_s_285.npy
# Se encontró el archivo or_s_286.npy
# Señal con armónico y Swell guardada en hrc_sw_s_286.npy
# Se encontró el archivo or_s_287.npy
# Señal con armónico y Swell guardada en hrc_sw_s_287.npy
# Se encontró el archivo or_s_288.npy
# Señal con armónico y Swell guardada en hrc_sw_s_288.npy
# Se encontró el archivo or_s_289.npy
# Señal con armónico y Swell guardada en hrc_sw_s_289.npy
# Se encontró el archivo or_s_290.npy
# Señal con armónico y Swell guardada en hrc_sw_s_290.npy
# Se encontró el archivo or_s_291.npy
# Señal con armónico y Swell guardada en hrc_sw_s_291.npy
# Se encontró el archivo or_s_292.npy
# Señal con armónico y Swell guardada en hrc_sw_s_292.npy
# Se encontró el archivo or_s_293.npy
# Señal con armónico y Swell guardada en hrc_sw_s_293.npy
# Se encontró el archivo or_s_294.npy
# Señal con armónico y Swell guardada en hrc_sw_s_294.npy
# Se encontró el archivo or_s_295.npy
# Señal con armónico y Swell guardada en hrc_sw_s_295.npy
# Se encontró el archivo or_s_296.npy
# Señal con armónico y Swell guardada en hrc_sw_s_296.npy
# Se encontró el archivo or_s_297.npy
# Señal con armónico y Swell guardada en hrc_sw_s_297.npy
# Se encontró el archivo or_s_298.npy
# Señal con armónico y Swell guardada en hrc_sw_s_298.npy
# Se encontró el archivo or_s_299.npy
# Señal con armónico y Swell guardada en hrc_sw_s_299.npy
# Se encontró el archivo or_s_300.npy
# Señal con armónico y Swell guardada en hrc_sw_s_300.npy
# Se encontró el archivo or_s_301.npy
# Señal con armónico y Swell guardada en hrc_sw_s_301.npy
# Se encontró el archivo or_s_302.npy
# Señal con armónico y Swell guardada en hrc_sw_s_302.npy
# Se encontró el archivo or_s_303.npy
# Señal con armónico y Swell guardada en hrc_sw_s_303.npy
# Se encontró el archivo or_s_304.npy
# Señal con armónico y Swell guardada en hrc_sw_s_304.npy
# Se encontró el archivo or_s_305.npy
# Señal con armónico y Swell guardada en hrc_sw_s_305.npy
# Se encontró el archivo or_s_306.npy
# Señal con armónico y Swell guardada en hrc_sw_s_306.npy
# Se encontró el archivo or_s_307.npy
# Señal con armónico y Swell guardada en hrc_sw_s_307.npy
# Se encontró el archivo or_s_308.npy
# Señal con armónico y Swell guardada en hrc_sw_s_308.npy
# Se encontró el archivo or_s_309.npy
# Señal con armónico y Swell guardada en hrc_sw_s_309.npy
# Se encontró el archivo or_s_310.npy
# Señal con armónico y Swell guardada en hrc_sw_s_310.npy
# Se encontró el archivo or_s_311.npy
# Señal con armónico y Swell guardada en hrc_sw_s_311.npy
# Se encontró el archivo or_s_312.npy
# Señal con armónico y Swell guardada en hrc_sw_s_312.npy
# Se encontró el archivo or_s_313.npy
# Señal con armónico y Swell guardada en hrc_sw_s_313.npy
# Se encontró el archivo or_s_314.npy
# Señal con armónico y Swell guardada en hrc_sw_s_314.npy
# Se encontró el archivo or_s_315.npy
# Señal con armónico y Swell guardada en hrc_sw_s_315.npy
# Se encontró el archivo or_s_316.npy
# Señal con armónico y Swell guardada en hrc_sw_s_316.npy
# Se encontró el archivo or_s_317.npy
# Señal con armónico y Swell guardada en hrc_sw_s_317.npy
# Se encontró el archivo or_s_318.npy
# Señal con armónico y Swell guardada en hrc_sw_s_318.npy
# Se encontró el archivo or_s_319.npy
# Señal con armónico y Swell guardada en hrc_sw_s_319.npy
# Se encontró el archivo or_s_320.npy
# Señal con armónico y Swell guardada en hrc_sw_s_320.npy
# Se encontró el archivo or_s_321.npy
# Señal con armónico y Swell guardada en hrc_sw_s_321.npy
# Se encontró el archivo or_s_322.npy
# Señal con armónico y Swell guardada en hrc_sw_s_322.npy
# Se encontró el archivo or_s_323.npy
# Señal con armónico y Swell guardada en hrc_sw_s_323.npy
# Se encontró el archivo or_s_324.npy
# Señal con armónico y Swell guardada en hrc_sw_s_324.npy
# Se encontró el archivo or_s_325.npy
# Señal con armónico y Swell guardada en hrc_sw_s_325.npy
# Se encontró el archivo or_s_326.npy
# Señal con armónico y Swell guardada en hrc_sw_s_326.npy
# Se encontró el archivo or_s_327.npy
# Señal con armónico y Swell guardada en hrc_sw_s_327.npy
# Se encontró el archivo or_s_328.npy
# Señal con armónico y Swell guardada en hrc_sw_s_328.npy
# Se encontró el archivo or_s_329.npy
# Señal con armónico y Swell guardada en hrc_sw_s_329.npy
# Se encontró el archivo or_s_330.npy
# Señal con armónico y Swell guardada en hrc_sw_s_330.npy
# Se encontró el archivo or_s_331.npy
# Señal con armónico y Swell guardada en hrc_sw_s_331.npy
# Se encontró el archivo or_s_332.npy
# Señal con armónico y Swell guardada en hrc_sw_s_332.npy
# Se encontró el archivo or_s_333.npy
# Señal con armónico y Swell guardada en hrc_sw_s_333.npy
# Se encontró el archivo or_s_334.npy
# Señal con armónico y Swell guardada en hrc_sw_s_334.npy
# Se encontró el archivo or_s_335.npy
# Señal con armónico y Swell guardada en hrc_sw_s_335.npy
# Se encontró el archivo or_s_336.npy
# Señal con armónico y Swell guardada en hrc_sw_s_336.npy
# Se encontró el archivo or_s_337.npy
# Señal con armónico y Swell guardada en hrc_sw_s_337.npy
# Se encontró el archivo or_s_338.npy
# Señal con armónico y Swell guardada en hrc_sw_s_338.npy
# Se encontró el archivo or_s_339.npy
# Señal con armónico y Swell guardada en hrc_sw_s_339.npy
# Se encontró el archivo or_s_340.npy
# Señal con armónico y Swell guardada en hrc_sw_s_340.npy
# Se encontró el archivo or_s_341.npy
# Señal con armónico y Swell guardada en hrc_sw_s_341.npy
# Se encontró el archivo or_s_342.npy
# Señal con armónico y Swell guardada en hrc_sw_s_342.npy
# Se encontró el archivo or_s_343.npy
# Señal con armónico y Swell guardada en hrc_sw_s_343.npy
# Se encontró el archivo or_s_344.npy
# Señal con armónico y Swell guardada en hrc_sw_s_344.npy
# Se encontró el archivo or_s_345.npy
# Señal con armónico y Swell guardada en hrc_sw_s_345.npy
# Se encontró el archivo or_s_346.npy
# Señal con armónico y Swell guardada en hrc_sw_s_346.npy
# Se encontró el archivo or_s_347.npy
# Señal con armónico y Swell guardada en hrc_sw_s_347.npy
# Se encontró el archivo or_s_348.npy
# Señal con armónico y Swell guardada en hrc_sw_s_348.npy
# Se encontró el archivo or_s_349.npy
# Señal con armónico y Swell guardada en hrc_sw_s_349.npy
# Se encontró el archivo or_s_350.npy
# Señal con armónico y Swell guardada en hrc_sw_s_350.npy
# Se encontró el archivo or_s_351.npy
# Señal con armónico y Swell guardada en hrc_sw_s_351.npy
# Se encontró el archivo or_s_352.npy
# Señal con armónico y Swell guardada en hrc_sw_s_352.npy
# Se encontró el archivo or_s_353.npy
# Señal con armónico y Swell guardada en hrc_sw_s_353.npy
# Se encontró el archivo or_s_354.npy
# Señal con armónico y Swell guardada en hrc_sw_s_354.npy
# Se encontró el archivo or_s_355.npy
# Señal con armónico y Swell guardada en hrc_sw_s_355.npy
# Se encontró el archivo or_s_356.npy
# Señal con armónico y Swell guardada en hrc_sw_s_356.npy
# Se encontró el archivo or_s_357.npy
# Señal con armónico y Swell guardada en hrc_sw_s_357.npy
# Se encontró el archivo or_s_358.npy
# Señal con armónico y Swell guardada en hrc_sw_s_358.npy
# Se encontró el archivo or_s_359.npy
# Señal con armónico y Swell guardada en hrc_sw_s_359.npy
# Se encontró el archivo or_s_360.npy
# Señal con armónico y Swell guardada en hrc_sw_s_360.npy
# Se encontró el archivo or_s_361.npy
# Señal con armónico y Swell guardada en hrc_sw_s_361.npy
# Se encontró el archivo or_s_362.npy
# Señal con armónico y Swell guardada en hrc_sw_s_362.npy
# Se encontró el archivo or_s_363.npy
# Señal con armónico y Swell guardada en hrc_sw_s_363.npy
# Se encontró el archivo or_s_364.npy
# Señal con armónico y Swell guardada en hrc_sw_s_364.npy
# Se encontró el archivo or_s_365.npy
# Señal con armónico y Swell guardada en hrc_sw_s_365.npy
# Se encontró el archivo or_s_366.npy
# Señal con armónico y Swell guardada en hrc_sw_s_366.npy
# Se encontró el archivo or_s_367.npy
# Señal con armónico y Swell guardada en hrc_sw_s_367.npy
# Se encontró el archivo or_s_368.npy
# Señal con armónico y Swell guardada en hrc_sw_s_368.npy
# Se encontró el archivo or_s_369.npy
# Señal con armónico y Swell guardada en hrc_sw_s_369.npy
# Se encontró el archivo or_s_370.npy
# Señal con armónico y Swell guardada en hrc_sw_s_370.npy
# Se encontró el archivo or_s_371.npy
# Señal con armónico y Swell guardada en hrc_sw_s_371.npy
# Se encontró el archivo or_s_372.npy
# Señal con armónico y Swell guardada en hrc_sw_s_372.npy
# Se encontró el archivo or_s_373.npy
# Señal con armónico y Swell guardada en hrc_sw_s_373.npy
# Se encontró el archivo or_s_374.npy
# Señal con armónico y Swell guardada en hrc_sw_s_374.npy
# Se encontró el archivo or_s_375.npy
# Señal con armónico y Swell guardada en hrc_sw_s_375.npy
# Se encontró el archivo or_s_376.npy
# Señal con armónico y Swell guardada en hrc_sw_s_376.npy
# Se encontró el archivo or_s_377.npy
# Señal con armónico y Swell guardada en hrc_sw_s_377.npy
# Se encontró el archivo or_s_378.npy
# Señal con armónico y Swell guardada en hrc_sw_s_378.npy
# Se encontró el archivo or_s_379.npy
# Señal con armónico y Swell guardada en hrc_sw_s_379.npy
# Se encontró el archivo or_s_380.npy
# Señal con armónico y Swell guardada en hrc_sw_s_380.npy
# Se encontró el archivo or_s_381.npy
# Señal con armónico y Swell guardada en hrc_sw_s_381.npy
# Se encontró el archivo or_s_382.npy
# Señal con armónico y Swell guardada en hrc_sw_s_382.npy
# Se encontró el archivo or_s_383.npy
# Señal con armónico y Swell guardada en hrc_sw_s_383.npy
# Se encontró el archivo or_s_384.npy
# Señal con armónico y Swell guardada en hrc_sw_s_384.npy
# Se encontró el archivo or_s_385.npy
# Señal con armónico y Swell guardada en hrc_sw_s_385.npy
# Se encontró el archivo or_s_386.npy
# Señal con armónico y Swell guardada en hrc_sw_s_386.npy
# Se encontró el archivo or_s_387.npy
# Señal con armónico y Swell guardada en hrc_sw_s_387.npy
# Se encontró el archivo or_s_388.npy
# Señal con armónico y Swell guardada en hrc_sw_s_388.npy
# Se encontró el archivo or_s_389.npy
# Señal con armónico y Swell guardada en hrc_sw_s_389.npy
# Se encontró el archivo or_s_390.npy
# Señal con armónico y Swell guardada en hrc_sw_s_390.npy
# Se encontró el archivo or_s_391.npy
# Señal con armónico y Swell guardada en hrc_sw_s_391.npy
# Se encontró el archivo or_s_392.npy
# Señal con armónico y Swell guardada en hrc_sw_s_392.npy
# Se encontró el archivo or_s_393.npy
# Señal con armónico y Swell guardada en hrc_sw_s_393.npy
# Se encontró el archivo or_s_394.npy
# Señal con armónico y Swell guardada en hrc_sw_s_394.npy
# Se encontró el archivo or_s_395.npy
# Señal con armónico y Swell guardada en hrc_sw_s_395.npy
# Se encontró el archivo or_s_396.npy
# Señal con armónico y Swell guardada en hrc_sw_s_396.npy
# Se encontró el archivo or_s_397.npy
# Señal con armónico y Swell guardada en hrc_sw_s_397.npy
# Se encontró el archivo or_s_398.npy
# Señal con armónico y Swell guardada en hrc_sw_s_398.npy
# Se encontró el archivo or_s_399.npy
# Señal con armónico y Swell guardada en hrc_sw_s_399.npy
# Se encontró el archivo or_s_400.npy
# Señal con armónico y Swell guardada en hrc_sw_s_400.npy
# Se encontró el archivo or_s_401.npy
# Señal con armónico y Swell guardada en hrc_sw_s_401.npy
# Se encontró el archivo or_s_402.npy
# Señal con armónico y Swell guardada en hrc_sw_s_402.npy
# Se encontró el archivo or_s_403.npy
# Señal con armónico y Swell guardada en hrc_sw_s_403.npy
# Se encontró el archivo or_s_404.npy
# Señal con armónico y Swell guardada en hrc_sw_s_404.npy
# Se encontró el archivo or_s_405.npy
# Señal con armónico y Swell guardada en hrc_sw_s_405.npy
# Se encontró el archivo or_s_406.npy
# Señal con armónico y Swell guardada en hrc_sw_s_406.npy
# Se encontró el archivo or_s_407.npy
# Señal con armónico y Swell guardada en hrc_sw_s_407.npy
# Se encontró el archivo or_s_408.npy
# Señal con armónico y Swell guardada en hrc_sw_s_408.npy
# Se encontró el archivo or_s_409.npy
# Señal con armónico y Swell guardada en hrc_sw_s_409.npy
# Se encontró el archivo or_s_410.npy
# Señal con armónico y Swell guardada en hrc_sw_s_410.npy
# Se encontró el archivo or_s_411.npy
# Señal con armónico y Swell guardada en hrc_sw_s_411.npy
# Se encontró el archivo or_s_412.npy
# Señal con armónico y Swell guardada en hrc_sw_s_412.npy
# Se encontró el archivo or_s_413.npy
# Señal con armónico y Swell guardada en hrc_sw_s_413.npy
# Se encontró el archivo or_s_414.npy
# Señal con armónico y Swell guardada en hrc_sw_s_414.npy
# Se encontró el archivo or_s_415.npy
# Señal con armónico y Swell guardada en hrc_sw_s_415.npy
# Se encontró el archivo or_s_416.npy
# Señal con armónico y Swell guardada en hrc_sw_s_416.npy
# Se encontró el archivo or_s_417.npy
# Señal con armónico y Swell guardada en hrc_sw_s_417.npy
# Se encontró el archivo or_s_418.npy
# Señal con armónico y Swell guardada en hrc_sw_s_418.npy
# Se encontró el archivo or_s_419.npy
# Señal con armónico y Swell guardada en hrc_sw_s_419.npy
# Se encontró el archivo or_s_420.npy
# Señal con armónico y Swell guardada en hrc_sw_s_420.npy
# Se encontró el archivo or_s_421.npy
# Señal con armónico y Swell guardada en hrc_sw_s_421.npy
# Se encontró el archivo or_s_422.npy
# Señal con armónico y Swell guardada en hrc_sw_s_422.npy
# Se encontró el archivo or_s_423.npy
# Señal con armónico y Swell guardada en hrc_sw_s_423.npy
# Se encontró el archivo or_s_424.npy
# Señal con armónico y Swell guardada en hrc_sw_s_424.npy
# Se encontró el archivo or_s_425.npy
# Señal con armónico y Swell guardada en hrc_sw_s_425.npy
# Se encontró el archivo or_s_426.npy
# Señal con armónico y Swell guardada en hrc_sw_s_426.npy
# Se encontró el archivo or_s_427.npy
# Señal con armónico y Swell guardada en hrc_sw_s_427.npy
# Se encontró el archivo or_s_428.npy
# Señal con armónico y Swell guardada en hrc_sw_s_428.npy
# Se encontró el archivo or_s_429.npy
# Señal con armónico y Swell guardada en hrc_sw_s_429.npy
# Se encontró el archivo or_s_430.npy
# Señal con armónico y Swell guardada en hrc_sw_s_430.npy
# Se encontró el archivo or_s_431.npy
# Señal con armónico y Swell guardada en hrc_sw_s_431.npy
# Se encontró el archivo or_s_432.npy
# Señal con armónico y Swell guardada en hrc_sw_s_432.npy
# Se encontró el archivo or_s_433.npy
# Señal con armónico y Swell guardada en hrc_sw_s_433.npy
# Se encontró el archivo or_s_434.npy
# Señal con armónico y Swell guardada en hrc_sw_s_434.npy
# Se encontró el archivo or_s_435.npy
# Señal con armónico y Swell guardada en hrc_sw_s_435.npy
# Se encontró el archivo or_s_436.npy
# Señal con armónico y Swell guardada en hrc_sw_s_436.npy
# Se encontró el archivo or_s_437.npy
# Señal con armónico y Swell guardada en hrc_sw_s_437.npy
# Se encontró el archivo or_s_438.npy
# Señal con armónico y Swell guardada en hrc_sw_s_438.npy
# Se encontró el archivo or_s_439.npy
# Señal con armónico y Swell guardada en hrc_sw_s_439.npy
# Se encontró el archivo or_s_440.npy
# Señal con armónico y Swell guardada en hrc_sw_s_440.npy
# Se encontró el archivo or_s_441.npy
# Señal con armónico y Swell guardada en hrc_sw_s_441.npy
# Se encontró el archivo or_s_442.npy
# Señal con armónico y Swell guardada en hrc_sw_s_442.npy
# Se encontró el archivo or_s_443.npy
# Señal con armónico y Swell guardada en hrc_sw_s_443.npy
# Se encontró el archivo or_s_444.npy
# Señal con armónico y Swell guardada en hrc_sw_s_444.npy
# Se encontró el archivo or_s_445.npy
# Señal con armónico y Swell guardada en hrc_sw_s_445.npy
# Se encontró el archivo or_s_446.npy
# Señal con armónico y Swell guardada en hrc_sw_s_446.npy
# Se encontró el archivo or_s_447.npy
# Señal con armónico y Swell guardada en hrc_sw_s_447.npy
# Se encontró el archivo or_s_448.npy
# Señal con armónico y Swell guardada en hrc_sw_s_448.npy
# Se encontró el archivo or_s_449.npy
# Señal con armónico y Swell guardada en hrc_sw_s_449.npy
# Se encontró el archivo or_s_450.npy
# Señal con armónico y Swell guardada en hrc_sw_s_450.npy
# Se encontró el archivo or_s_451.npy
# Señal con armónico y Swell guardada en hrc_sw_s_451.npy
# Se encontró el archivo or_s_452.npy
# Señal con armónico y Swell guardada en hrc_sw_s_452.npy
# Se encontró el archivo or_s_453.npy
# Señal con armónico y Swell guardada en hrc_sw_s_453.npy
# Se encontró el archivo or_s_454.npy
# Señal con armónico y Swell guardada en hrc_sw_s_454.npy
# Se encontró el archivo or_s_455.npy
# Señal con armónico y Swell guardada en hrc_sw_s_455.npy
# Se encontró el archivo or_s_456.npy
# Señal con armónico y Swell guardada en hrc_sw_s_456.npy
# Se encontró el archivo or_s_457.npy
# Señal con armónico y Swell guardada en hrc_sw_s_457.npy
# Se encontró el archivo or_s_458.npy
# Señal con armónico y Swell guardada en hrc_sw_s_458.npy
# Se encontró el archivo or_s_459.npy
# Señal con armónico y Swell guardada en hrc_sw_s_459.npy
# Se encontró el archivo or_s_460.npy
# Señal con armónico y Swell guardada en hrc_sw_s_460.npy
# Se encontró el archivo or_s_461.npy
# Señal con armónico y Swell guardada en hrc_sw_s_461.npy
# Se encontró el archivo or_s_462.npy
# Señal con armónico y Swell guardada en hrc_sw_s_462.npy
# Se encontró el archivo or_s_463.npy
# Señal con armónico y Swell guardada en hrc_sw_s_463.npy
# Se encontró el archivo or_s_464.npy
# Señal con armónico y Swell guardada en hrc_sw_s_464.npy
# Se encontró el archivo or_s_465.npy
# Señal con armónico y Swell guardada en hrc_sw_s_465.npy
# Se encontró el archivo or_s_466.npy
# Señal con armónico y Swell guardada en hrc_sw_s_466.npy
# Se encontró el archivo or_s_467.npy
# Señal con armónico y Swell guardada en hrc_sw_s_467.npy
# Se encontró el archivo or_s_468.npy
# Señal con armónico y Swell guardada en hrc_sw_s_468.npy
# Se encontró el archivo or_s_469.npy
# Señal con armónico y Swell guardada en hrc_sw_s_469.npy
# Se encontró el archivo or_s_470.npy
# Señal con armónico y Swell guardada en hrc_sw_s_470.npy
# Se encontró el archivo or_s_471.npy
# Señal con armónico y Swell guardada en hrc_sw_s_471.npy
# Se encontró el archivo or_s_472.npy
# Señal con armónico y Swell guardada en hrc_sw_s_472.npy
# Se encontró el archivo or_s_473.npy
# Señal con armónico y Swell guardada en hrc_sw_s_473.npy
# Se encontró el archivo or_s_474.npy
# Señal con armónico y Swell guardada en hrc_sw_s_474.npy
# Se encontró el archivo or_s_475.npy
# Señal con armónico y Swell guardada en hrc_sw_s_475.npy
# Se encontró el archivo or_s_476.npy
# Señal con armónico y Swell guardada en hrc_sw_s_476.npy
# Se encontró el archivo or_s_477.npy
# Señal con armónico y Swell guardada en hrc_sw_s_477.npy
# Se encontró el archivo or_s_478.npy
# Señal con armónico y Swell guardada en hrc_sw_s_478.npy
# Se encontró el archivo or_s_479.npy
# Señal con armónico y Swell guardada en hrc_sw_s_479.npy
# Se encontró el archivo or_s_480.npy
# Señal con armónico y Swell guardada en hrc_sw_s_480.npy
# Se encontró el archivo or_s_481.npy
# Señal con armónico y Swell guardada en hrc_sw_s_481.npy
# Se encontró el archivo or_s_482.npy
# Señal con armónico y Swell guardada en hrc_sw_s_482.npy
# Se encontró el archivo or_s_483.npy
# Señal con armónico y Swell guardada en hrc_sw_s_483.npy
# Se encontró el archivo or_s_484.npy
# Señal con armónico y Swell guardada en hrc_sw_s_484.npy
# Se encontró el archivo or_s_485.npy
# Señal con armónico y Swell guardada en hrc_sw_s_485.npy
# Se encontró el archivo or_s_486.npy
# Señal con armónico y Swell guardada en hrc_sw_s_486.npy
# Se encontró el archivo or_s_487.npy
# Señal con armónico y Swell guardada en hrc_sw_s_487.npy
# Se encontró el archivo or_s_488.npy
# Señal con armónico y Swell guardada en hrc_sw_s_488.npy
# Se encontró el archivo or_s_489.npy
# Señal con armónico y Swell guardada en hrc_sw_s_489.npy
# Se encontró el archivo or_s_490.npy
# Señal con armónico y Swell guardada en hrc_sw_s_490.npy
# Se encontró el archivo or_s_491.npy
# Señal con armónico y Swell guardada en hrc_sw_s_491.npy
# Se encontró el archivo or_s_492.npy
# Señal con armónico y Swell guardada en hrc_sw_s_492.npy
# Se encontró el archivo or_s_493.npy
# Señal con armónico y Swell guardada en hrc_sw_s_493.npy
# Se encontró el archivo or_s_494.npy
# Señal con armónico y Swell guardada en hrc_sw_s_494.npy
# Se encontró el archivo or_s_495.npy
# Señal con armónico y Swell guardada en hrc_sw_s_495.npy
# Se encontró el archivo or_s_496.npy
# Señal con armónico y Swell guardada en hrc_sw_s_496.npy
# Se encontró el archivo or_s_497.npy
# Señal con armónico y Swell guardada en hrc_sw_s_497.npy
# Se encontró el archivo or_s_498.npy
# Señal con armónico y Swell guardada en hrc_sw_s_498.npy
# Se encontró el archivo or_s_499.npy
# Señal con armónico y Swell guardada en hrc_sw_s_499.npy
# Se encontró el archivo or_s_500.npy
# Señal con armónico y Swell guardada en hrc_sw_s_500.npy
# Se encontró el archivo or_s_501.npy
# Señal con armónico y Swell guardada en hrc_sw_s_501.npy
# Se encontró el archivo or_s_502.npy
# Señal con armónico y Swell guardada en hrc_sw_s_502.npy
# Se encontró el archivo or_s_503.npy
# Señal con armónico y Swell guardada en hrc_sw_s_503.npy
# Se encontró el archivo or_s_504.npy
# Señal con armónico y Swell guardada en hrc_sw_s_504.npy
# Se encontró el archivo or_s_505.npy
# Señal con armónico y Swell guardada en hrc_sw_s_505.npy
# Se encontró el archivo or_s_506.npy
# Señal con armónico y Swell guardada en hrc_sw_s_506.npy
# Se encontró el archivo or_s_507.npy
# Señal con armónico y Swell guardada en hrc_sw_s_507.npy
# Se encontró el archivo or_s_508.npy
# Señal con armónico y Swell guardada en hrc_sw_s_508.npy
# Se encontró el archivo or_s_509.npy
# Señal con armónico y Swell guardada en hrc_sw_s_509.npy
# Se encontró el archivo or_s_510.npy
# Señal con armónico y Swell guardada en hrc_sw_s_510.npy
# Se encontró el archivo or_s_511.npy
# Señal con armónico y Swell guardada en hrc_sw_s_511.npy
# Se encontró el archivo or_s_512.npy
# Señal con armónico y Swell guardada en hrc_sw_s_512.npy
# Se encontró el archivo or_s_513.npy
# Señal con armónico y Swell guardada en hrc_sw_s_513.npy
# Se encontró el archivo or_s_514.npy
# Señal con armónico y Swell guardada en hrc_sw_s_514.npy
# Se encontró el archivo or_s_515.npy
# Señal con armónico y Swell guardada en hrc_sw_s_515.npy
# Se encontró el archivo or_s_516.npy
# Señal con armónico y Swell guardada en hrc_sw_s_516.npy
# Se encontró el archivo or_s_517.npy
# Señal con armónico y Swell guardada en hrc_sw_s_517.npy
# Se encontró el archivo or_s_518.npy
# Señal con armónico y Swell guardada en hrc_sw_s_518.npy
# Se encontró el archivo or_s_519.npy
# Señal con armónico y Swell guardada en hrc_sw_s_519.npy
# Se encontró el archivo or_s_520.npy
# Señal con armónico y Swell guardada en hrc_sw_s_520.npy
# Se encontró el archivo or_s_521.npy
# Señal con armónico y Swell guardada en hrc_sw_s_521.npy
# Se encontró el archivo or_s_522.npy
# Señal con armónico y Swell guardada en hrc_sw_s_522.npy
# Se encontró el archivo or_s_523.npy
# Señal con armónico y Swell guardada en hrc_sw_s_523.npy
# Se encontró el archivo or_s_524.npy
# ...
# Se encontró el archivo or_s_3433.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10633.npy
# Se encontró el archivo or_s_3434.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10634.npy
# Se encontró el archivo or_s_3435.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10635.npy
# Se encontró el archivo or_s_3436.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10636.npy
# Se encontró el archivo or_s_3437.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10637.npy
# Se encontró el archivo or_s_3438.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10638.npy
# Se encontró el archivo or_s_3439.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10639.npy
# Se encontró el archivo or_s_3440.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10640.npy
# Se encontró el archivo or_s_3441.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10641.npy
# Se encontró el archivo or_s_3442.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10642.npy
# Se encontró el archivo or_s_3443.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10643.npy
# Se encontró el archivo or_s_3444.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10644.npy
# Se encontró el archivo or_s_3445.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10645.npy
# Se encontró el archivo or_s_3446.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10646.npy
# Se encontró el archivo or_s_3447.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10647.npy
# Se encontró el archivo or_s_3448.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10648.npy
# Se encontró el archivo or_s_3449.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10649.npy
# Se encontró el archivo or_s_3450.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10650.npy
# Se encontró el archivo or_s_3451.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10651.npy
# Se encontró el archivo or_s_3452.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10652.npy
# Se encontró el archivo or_s_3453.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10653.npy
# Se encontró el archivo or_s_3454.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10654.npy
# Se encontró el archivo or_s_3455.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10655.npy
# Se encontró el archivo or_s_3456.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10656.npy
# Se encontró el archivo or_s_3457.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10657.npy
# Se encontró el archivo or_s_3458.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10658.npy
# Se encontró el archivo or_s_3459.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10659.npy
# Se encontró el archivo or_s_3460.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10660.npy
# Se encontró el archivo or_s_3461.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10661.npy
# Se encontró el archivo or_s_3462.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10662.npy
# Se encontró el archivo or_s_3463.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10663.npy
# Se encontró el archivo or_s_3464.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10664.npy
# Se encontró el archivo or_s_3465.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10665.npy
# Se encontró el archivo or_s_3466.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10666.npy
# Se encontró el archivo or_s_3467.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10667.npy
# Se encontró el archivo or_s_3468.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10668.npy
# Se encontró el archivo or_s_3469.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10669.npy
# Se encontró el archivo or_s_3470.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10670.npy
# Se encontró el archivo or_s_3471.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10671.npy
# Se encontró el archivo or_s_3472.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10672.npy
# Se encontró el archivo or_s_3473.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10673.npy
# Se encontró el archivo or_s_3474.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10674.npy
# Se encontró el archivo or_s_3475.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10675.npy
# Se encontró el archivo or_s_3476.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10676.npy
# Se encontró el archivo or_s_3477.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10677.npy
# Se encontró el archivo or_s_3478.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10678.npy
# Se encontró el archivo or_s_3479.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10679.npy
# Se encontró el archivo or_s_3480.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10680.npy
# Se encontró el archivo or_s_3481.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10681.npy
# Se encontró el archivo or_s_3482.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10682.npy
# Se encontró el archivo or_s_3483.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10683.npy
# Se encontró el archivo or_s_3484.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10684.npy
# Se encontró el archivo or_s_3485.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10685.npy
# Se encontró el archivo or_s_3486.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10686.npy
# Se encontró el archivo or_s_3487.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10687.npy
# Se encontró el archivo or_s_3488.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10688.npy
# Se encontró el archivo or_s_3489.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10689.npy
# Se encontró el archivo or_s_3490.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10690.npy
# Se encontró el archivo or_s_3491.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10691.npy
# Se encontró el archivo or_s_3492.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10692.npy
# Se encontró el archivo or_s_3493.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10693.npy
# Se encontró el archivo or_s_3494.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10694.npy
# Se encontró el archivo or_s_3495.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10695.npy
# Se encontró el archivo or_s_3496.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10696.npy
# Se encontró el archivo or_s_3497.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10697.npy
# Se encontró el archivo or_s_3498.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10698.npy
# Se encontró el archivo or_s_3499.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10699.npy
# Se encontró el archivo or_s_3500.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10700.npy
# Se encontró el archivo or_s_3501.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10701.npy
# Se encontró el archivo or_s_3502.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10702.npy
# Se encontró el archivo or_s_3503.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10703.npy
# Se encontró el archivo or_s_3504.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10704.npy
# Se encontró el archivo or_s_3505.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10705.npy
# Se encontró el archivo or_s_3506.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10706.npy
# Se encontró el archivo or_s_3507.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10707.npy
# Se encontró el archivo or_s_3508.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10708.npy
# Se encontró el archivo or_s_3509.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10709.npy
# Se encontró el archivo or_s_3510.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10710.npy
# Se encontró el archivo or_s_3511.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10711.npy
# Se encontró el archivo or_s_3512.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10712.npy
# Se encontró el archivo or_s_3513.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10713.npy
# Se encontró el archivo or_s_3514.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10714.npy
# Se encontró el archivo or_s_3515.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10715.npy
# Se encontró el archivo or_s_3516.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10716.npy
# Se encontró el archivo or_s_3517.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10717.npy
# Se encontró el archivo or_s_3518.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10718.npy
# Se encontró el archivo or_s_3519.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10719.npy
# Se encontró el archivo or_s_3520.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10720.npy
# Se encontró el archivo or_s_3521.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10721.npy
# Se encontró el archivo or_s_3522.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10722.npy
# Se encontró el archivo or_s_3523.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10723.npy
# Se encontró el archivo or_s_3524.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10724.npy
# Se encontró el archivo or_s_3525.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10725.npy
# Se encontró el archivo or_s_3526.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10726.npy
# Se encontró el archivo or_s_3527.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10727.npy
# Se encontró el archivo or_s_3528.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10728.npy
# Se encontró el archivo or_s_3529.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10729.npy
# Se encontró el archivo or_s_3530.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10730.npy
# Se encontró el archivo or_s_3531.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10731.npy
# Se encontró el archivo or_s_3532.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10732.npy
# Se encontró el archivo or_s_3533.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10733.npy
# Se encontró el archivo or_s_3534.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10734.npy
# Se encontró el archivo or_s_3535.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10735.npy
# Se encontró el archivo or_s_3536.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10736.npy
# Se encontró el archivo or_s_3537.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10737.npy
# Se encontró el archivo or_s_3538.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10738.npy
# Se encontró el archivo or_s_3539.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10739.npy
# Se encontró el archivo or_s_3540.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10740.npy
# Se encontró el archivo or_s_3541.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10741.npy
# Se encontró el archivo or_s_3542.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10742.npy
# Se encontró el archivo or_s_3543.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10743.npy
# Se encontró el archivo or_s_3544.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10744.npy
# Se encontró el archivo or_s_3545.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10745.npy
# Se encontró el archivo or_s_3546.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10746.npy
# Se encontró el archivo or_s_3547.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10747.npy
# Se encontró el archivo or_s_3548.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10748.npy
# Se encontró el archivo or_s_3549.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10749.npy
# Se encontró el archivo or_s_3550.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10750.npy
# Se encontró el archivo or_s_3551.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10751.npy
# Se encontró el archivo or_s_3552.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10752.npy
# Se encontró el archivo or_s_3553.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10753.npy
# Se encontró el archivo or_s_3554.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10754.npy
# Se encontró el archivo or_s_3555.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10755.npy
# Se encontró el archivo or_s_3556.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10756.npy
# Se encontró el archivo or_s_3557.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10757.npy
# Se encontró el archivo or_s_3558.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10758.npy
# Se encontró el archivo or_s_3559.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10759.npy
# Se encontró el archivo or_s_3560.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10760.npy
# Se encontró el archivo or_s_3561.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10761.npy
# Se encontró el archivo or_s_3562.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10762.npy
# Se encontró el archivo or_s_3563.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10763.npy
# Se encontró el archivo or_s_3564.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10764.npy
# Se encontró el archivo or_s_3565.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10765.npy
# Se encontró el archivo or_s_3566.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10766.npy
# Se encontró el archivo or_s_3567.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10767.npy
# Se encontró el archivo or_s_3568.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10768.npy
# Se encontró el archivo or_s_3569.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10769.npy
# Se encontró el archivo or_s_3570.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10770.npy
# Se encontró el archivo or_s_3571.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10771.npy
# Se encontró el archivo or_s_3572.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10772.npy
# Se encontró el archivo or_s_3573.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10773.npy
# Se encontró el archivo or_s_3574.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10774.npy
# Se encontró el archivo or_s_3575.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10775.npy
# Se encontró el archivo or_s_3576.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10776.npy
# Se encontró el archivo or_s_3577.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10777.npy
# Se encontró el archivo or_s_3578.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10778.npy
# Se encontró el archivo or_s_3579.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10779.npy
# Se encontró el archivo or_s_3580.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10780.npy
# Se encontró el archivo or_s_3581.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10781.npy
# Se encontró el archivo or_s_3582.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10782.npy
# Se encontró el archivo or_s_3583.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10783.npy
# Se encontró el archivo or_s_3584.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10784.npy
# Se encontró el archivo or_s_3585.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10785.npy
# Se encontró el archivo or_s_3586.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10786.npy
# Se encontró el archivo or_s_3587.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10787.npy
# Se encontró el archivo or_s_3588.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10788.npy
# Se encontró el archivo or_s_3589.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10789.npy
# Se encontró el archivo or_s_3590.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10790.npy
# Se encontró el archivo or_s_3591.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10791.npy
# Se encontró el archivo or_s_3592.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10792.npy
# Se encontró el archivo or_s_3593.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10793.npy
# Se encontró el archivo or_s_3594.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10794.npy
# Se encontró el archivo or_s_3595.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10795.npy
# Se encontró el archivo or_s_3596.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10796.npy
# Se encontró el archivo or_s_3597.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10797.npy
# Se encontró el archivo or_s_3598.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10798.npy
# Se encontró el archivo or_s_3599.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10799.npy
# Se encontró el archivo or_s_3600.npy
# Señal con armónico y Swell guardada en hrc_sw_s_10800.npy

# %%
# Generar un número aleatorio entre 1 y 3600 para seleccionar el archivo
import random

archivo_numero = random.randint(1, 2000)
archivo_path = os.path.join(os.getcwd(), 'Harmonic_Swell_signals','train',f'hrc_sw_s_{archivo_numero}.npy')

# Cargar el archivo completo
signal_data = np.load(archivo_path)

# Graficar todos los datos de la señal
plt.figure(figsize=(12, 6))
plt.plot(signal_data, color='b', linestyle='-', linewidth=0.8, label='Amplitud en el tiempo')
plt.title(f"Representación completa de la señal - Archivo hrc_sw_s_{archivo_numero}.npy")
plt.xlabel("Muestras")
plt.ylabel("Amplitud")
plt.legend()
plt.grid(True)
plt.show()
