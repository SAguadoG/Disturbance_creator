# %% [markdown]
# # Sag Generator

# %% [markdown]
# Como tenemos una señal ya en archivos de Python, solo vamos a necesitar instalar dos librerías.
# - *Os* para trabajar entre carpetas
# - *Numpy* para operar las señales.

# %%
import os
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# En este script, solo tenemos una sola función "sag_generator".
# - Primero hacemos una iteración de todos los archivos de la carpeta que se generó en el script "Signal_Extractor.ipynb".
# - Si la ruta es correcta, debería encontrae el archivo, una vez que se encuentra el archivo, para operar se manera más sencilla, se trabajan con señales normalizadas. En este caso se usará la normalizada por el RMS.
# - Después simplemente se define el afactor de amplitud de la señal, como es un sag, tendrá que ser menor que la señal nominal en un período de tiempo, los valores están definidos en la norma IEEE 1159.
# <img src=https://www.researchgate.net/profile/Carlos-Leon-21/publication/229007775/figure/fig1/AS:300698383208453@1448703489308/Standard-IEEE-1159.png>
# - Se elimina el print del final para no generar los 3600 datos en pantalla.

# %%
# Obtener el directorio actual del script
# directorio_actual = os.path.abspath(os.path.dirname(__file__)) Funcionaba cuando era un archivo '.py'
directorio_actual = os.path.dirname(os.path.abspath(''))

def sag_generator():
    for i in range(3601):
        nombre_archivo = f"or_s_{i}.npy"
        ruta_archivo = os.path.join(directorio_actual, 'original_signal', nombre_archivo)

        if os.path.exists(ruta_archivo):
            print(f"Se encontró el archivo {nombre_archivo}")
            # Cargar los datos desde el archivo .npy
            data = np.load(ruta_archivo)
            # Normalizar la señal al rango [-1, 1]
            signal_original = data / np.sqrt(np.mean(data**2))

            # Parámetros de la amplificación aleatoria
            longitud_signal = len(signal_original)
            duracion_amplificacion_min = 1000  # en muestras (0.1 segundos a una tasa de muestreo de 10,000 Hz)
            duracion_amplificacion_max = 9000  # en muestras (0.9 segundos a una tasa de muestreo de 10,000 Hz)
            factor_amplitud_min = 0.1
            factor_amplitud_max = 0.9
            
            # Generar una duración aleatoria de la reducción de amplitud
            duracion_amplificacion = np.random.randint(duracion_amplificacion_min , duracion_amplificacion_max)

            # Generar la posición aleatoria para la reducción de amplitud
            inicio_amplificacion = np.random.randint(0, longitud_signal - duracion_amplificacion)

            # Generar el factor de amplificación aleatorio
            factor_amplitud = np.random.uniform(factor_amplitud_min, factor_amplitud_max)

            # Aplicar la amplificación en la parte aleatoria de la señal original
            signal_amplificada = np.copy(signal_original)
            signal_amplificada[inicio_amplificacion:(inicio_amplificacion + duracion_amplificacion)] *= factor_amplitud

            # Guardar la señal amplificada en un nuevo archivo
            directorio_destino = os.path.join(directorio_actual, 'sag_signals')
            os.makedirs(directorio_destino, exist_ok=True)
            nombre_archivo_nuevo = f"sg_s_{i}.npy"
            ruta_archivo_nuevo = os.path.join(directorio_destino, nombre_archivo_nuevo)
            np.save(ruta_archivo_nuevo, signal_amplificada)
            #print(f"Señal amplificada guardada en {nombre_archivo_nuevo}")
        #else:
            #print(f"No se encontró el archivo {nombre_archivo}")


sag_generator()
# Out:
# No se encontró el archivo or_s_0.npy
# Se encontró el archivo or_s_1.npy
# Se encontró el archivo or_s_2.npy
# Se encontró el archivo or_s_3.npy
# Se encontró el archivo or_s_4.npy
# Se encontró el archivo or_s_5.npy
# Se encontró el archivo or_s_6.npy
# Se encontró el archivo or_s_7.npy
# Se encontró el archivo or_s_8.npy
# Se encontró el archivo or_s_9.npy
# Se encontró el archivo or_s_10.npy
# Se encontró el archivo or_s_11.npy
# Se encontró el archivo or_s_12.npy
# Se encontró el archivo or_s_13.npy
# Se encontró el archivo or_s_14.npy
# Se encontró el archivo or_s_15.npy
# Se encontró el archivo or_s_16.npy
# Se encontró el archivo or_s_17.npy
# Se encontró el archivo or_s_18.npy
# Se encontró el archivo or_s_19.npy
# Se encontró el archivo or_s_20.npy
# Se encontró el archivo or_s_21.npy
# Se encontró el archivo or_s_22.npy
# Se encontró el archivo or_s_23.npy
# Se encontró el archivo or_s_24.npy
# Se encontró el archivo or_s_25.npy
# Se encontró el archivo or_s_26.npy
# Se encontró el archivo or_s_27.npy
# Se encontró el archivo or_s_28.npy
# Se encontró el archivo or_s_29.npy
# Se encontró el archivo or_s_30.npy
# Se encontró el archivo or_s_31.npy
# Se encontró el archivo or_s_32.npy
# Se encontró el archivo or_s_33.npy
# Se encontró el archivo or_s_34.npy
# Se encontró el archivo or_s_35.npy
# Se encontró el archivo or_s_36.npy
# Se encontró el archivo or_s_37.npy
# Se encontró el archivo or_s_38.npy
# Se encontró el archivo or_s_39.npy
# Se encontró el archivo or_s_40.npy
# Se encontró el archivo or_s_41.npy
# Se encontró el archivo or_s_42.npy
# Se encontró el archivo or_s_43.npy
# Se encontró el archivo or_s_44.npy
# Se encontró el archivo or_s_45.npy
# Se encontró el archivo or_s_46.npy
# Se encontró el archivo or_s_47.npy
# Se encontró el archivo or_s_48.npy
# Se encontró el archivo or_s_49.npy
# Se encontró el archivo or_s_50.npy
# Se encontró el archivo or_s_51.npy
# Se encontró el archivo or_s_52.npy
# Se encontró el archivo or_s_53.npy
# Se encontró el archivo or_s_54.npy
# Se encontró el archivo or_s_55.npy
# Se encontró el archivo or_s_56.npy
# Se encontró el archivo or_s_57.npy
# Se encontró el archivo or_s_58.npy
# Se encontró el archivo or_s_59.npy
# Se encontró el archivo or_s_60.npy
# Se encontró el archivo or_s_61.npy
# Se encontró el archivo or_s_62.npy
# Se encontró el archivo or_s_63.npy
# Se encontró el archivo or_s_64.npy
# Se encontró el archivo or_s_65.npy
# Se encontró el archivo or_s_66.npy
# Se encontró el archivo or_s_67.npy
# Se encontró el archivo or_s_68.npy
# Se encontró el archivo or_s_69.npy
# Se encontró el archivo or_s_70.npy
# Se encontró el archivo or_s_71.npy
# Se encontró el archivo or_s_72.npy
# Se encontró el archivo or_s_73.npy
# Se encontró el archivo or_s_74.npy
# Se encontró el archivo or_s_75.npy
# Se encontró el archivo or_s_76.npy
# Se encontró el archivo or_s_77.npy
# Se encontró el archivo or_s_78.npy
# Se encontró el archivo or_s_79.npy
# Se encontró el archivo or_s_80.npy
# Se encontró el archivo or_s_81.npy
# Se encontró el archivo or_s_82.npy
# Se encontró el archivo or_s_83.npy
# Se encontró el archivo or_s_84.npy
# Se encontró el archivo or_s_85.npy
# Se encontró el archivo or_s_86.npy
# Se encontró el archivo or_s_87.npy
# Se encontró el archivo or_s_88.npy
# Se encontró el archivo or_s_89.npy
# Se encontró el archivo or_s_90.npy
# Se encontró el archivo or_s_91.npy
# Se encontró el archivo or_s_92.npy
# Se encontró el archivo or_s_93.npy
# Se encontró el archivo or_s_94.npy
# Se encontró el archivo or_s_95.npy
# Se encontró el archivo or_s_96.npy
# Se encontró el archivo or_s_97.npy
# Se encontró el archivo or_s_98.npy
# Se encontró el archivo or_s_99.npy
# Se encontró el archivo or_s_100.npy
# Se encontró el archivo or_s_101.npy
# Se encontró el archivo or_s_102.npy
# Se encontró el archivo or_s_103.npy
# Se encontró el archivo or_s_104.npy
# Se encontró el archivo or_s_105.npy
# Se encontró el archivo or_s_106.npy
# Se encontró el archivo or_s_107.npy
# Se encontró el archivo or_s_108.npy
# Se encontró el archivo or_s_109.npy
# Se encontró el archivo or_s_110.npy
# Se encontró el archivo or_s_111.npy
# Se encontró el archivo or_s_112.npy
# Se encontró el archivo or_s_113.npy
# Se encontró el archivo or_s_114.npy
# Se encontró el archivo or_s_115.npy
# Se encontró el archivo or_s_116.npy
# Se encontró el archivo or_s_117.npy
# Se encontró el archivo or_s_118.npy
# Se encontró el archivo or_s_119.npy
# Se encontró el archivo or_s_120.npy
# Se encontró el archivo or_s_121.npy
# Se encontró el archivo or_s_122.npy
# Se encontró el archivo or_s_123.npy
# Se encontró el archivo or_s_124.npy
# Se encontró el archivo or_s_125.npy
# Se encontró el archivo or_s_126.npy
# Se encontró el archivo or_s_127.npy
# Se encontró el archivo or_s_128.npy
# Se encontró el archivo or_s_129.npy
# Se encontró el archivo or_s_130.npy
# Se encontró el archivo or_s_131.npy
# Se encontró el archivo or_s_132.npy
# Se encontró el archivo or_s_133.npy
# Se encontró el archivo or_s_134.npy
# Se encontró el archivo or_s_135.npy
# Se encontró el archivo or_s_136.npy
# Se encontró el archivo or_s_137.npy
# Se encontró el archivo or_s_138.npy
# Se encontró el archivo or_s_139.npy
# Se encontró el archivo or_s_140.npy
# Se encontró el archivo or_s_141.npy
# Se encontró el archivo or_s_142.npy
# Se encontró el archivo or_s_143.npy
# Se encontró el archivo or_s_144.npy
# Se encontró el archivo or_s_145.npy
# Se encontró el archivo or_s_146.npy
# Se encontró el archivo or_s_147.npy
# Se encontró el archivo or_s_148.npy
# Se encontró el archivo or_s_149.npy
# Se encontró el archivo or_s_150.npy
# Se encontró el archivo or_s_151.npy
# Se encontró el archivo or_s_152.npy
# Se encontró el archivo or_s_153.npy
# Se encontró el archivo or_s_154.npy
# Se encontró el archivo or_s_155.npy
# Se encontró el archivo or_s_156.npy
# Se encontró el archivo or_s_157.npy
# Se encontró el archivo or_s_158.npy
# Se encontró el archivo or_s_159.npy
# Se encontró el archivo or_s_160.npy
# Se encontró el archivo or_s_161.npy
# Se encontró el archivo or_s_162.npy
# Se encontró el archivo or_s_163.npy
# Se encontró el archivo or_s_164.npy
# Se encontró el archivo or_s_165.npy
# Se encontró el archivo or_s_166.npy
# Se encontró el archivo or_s_167.npy
# Se encontró el archivo or_s_168.npy
# Se encontró el archivo or_s_169.npy
# Se encontró el archivo or_s_170.npy
# Se encontró el archivo or_s_171.npy
# Se encontró el archivo or_s_172.npy
# Se encontró el archivo or_s_173.npy
# Se encontró el archivo or_s_174.npy
# Se encontró el archivo or_s_175.npy
# Se encontró el archivo or_s_176.npy
# Se encontró el archivo or_s_177.npy
# Se encontró el archivo or_s_178.npy
# Se encontró el archivo or_s_179.npy
# Se encontró el archivo or_s_180.npy
# Se encontró el archivo or_s_181.npy
# Se encontró el archivo or_s_182.npy
# Se encontró el archivo or_s_183.npy
# Se encontró el archivo or_s_184.npy
# Se encontró el archivo or_s_185.npy
# Se encontró el archivo or_s_186.npy
# Se encontró el archivo or_s_187.npy
# Se encontró el archivo or_s_188.npy
# Se encontró el archivo or_s_189.npy
# Se encontró el archivo or_s_190.npy
# Se encontró el archivo or_s_191.npy
# Se encontró el archivo or_s_192.npy
# Se encontró el archivo or_s_193.npy
# Se encontró el archivo or_s_194.npy
# Se encontró el archivo or_s_195.npy
# Se encontró el archivo or_s_196.npy
# Se encontró el archivo or_s_197.npy
# Se encontró el archivo or_s_198.npy
# Se encontró el archivo or_s_199.npy
# Se encontró el archivo or_s_200.npy
# Se encontró el archivo or_s_201.npy
# Se encontró el archivo or_s_202.npy
# Se encontró el archivo or_s_203.npy
# Se encontró el archivo or_s_204.npy
# Se encontró el archivo or_s_205.npy
# Se encontró el archivo or_s_206.npy
# Se encontró el archivo or_s_207.npy
# Se encontró el archivo or_s_208.npy
# Se encontró el archivo or_s_209.npy
# Se encontró el archivo or_s_210.npy
# Se encontró el archivo or_s_211.npy
# Se encontró el archivo or_s_212.npy
# Se encontró el archivo or_s_213.npy
# Se encontró el archivo or_s_214.npy
# Se encontró el archivo or_s_215.npy
# Se encontró el archivo or_s_216.npy
# Se encontró el archivo or_s_217.npy
# Se encontró el archivo or_s_218.npy
# Se encontró el archivo or_s_219.npy
# Se encontró el archivo or_s_220.npy
# Se encontró el archivo or_s_221.npy
# Se encontró el archivo or_s_222.npy
# Se encontró el archivo or_s_223.npy
# Se encontró el archivo or_s_224.npy
# Se encontró el archivo or_s_225.npy
# Se encontró el archivo or_s_226.npy
# Se encontró el archivo or_s_227.npy
# Se encontró el archivo or_s_228.npy
# Se encontró el archivo or_s_229.npy
# Se encontró el archivo or_s_230.npy
# Se encontró el archivo or_s_231.npy
# Se encontró el archivo or_s_232.npy
# Se encontró el archivo or_s_233.npy
# Se encontró el archivo or_s_234.npy
# Se encontró el archivo or_s_235.npy
# Se encontró el archivo or_s_236.npy
# Se encontró el archivo or_s_237.npy
# Se encontró el archivo or_s_238.npy
# Se encontró el archivo or_s_239.npy
# Se encontró el archivo or_s_240.npy
# Se encontró el archivo or_s_241.npy
# Se encontró el archivo or_s_242.npy
# Se encontró el archivo or_s_243.npy
# Se encontró el archivo or_s_244.npy
# Se encontró el archivo or_s_245.npy
# Se encontró el archivo or_s_246.npy
# Se encontró el archivo or_s_247.npy
# Se encontró el archivo or_s_248.npy
# Se encontró el archivo or_s_249.npy
# Se encontró el archivo or_s_250.npy
# Se encontró el archivo or_s_251.npy
# Se encontró el archivo or_s_252.npy
# Se encontró el archivo or_s_253.npy
# Se encontró el archivo or_s_254.npy
# Se encontró el archivo or_s_255.npy
# Se encontró el archivo or_s_256.npy
# Se encontró el archivo or_s_257.npy
# Se encontró el archivo or_s_258.npy
# Se encontró el archivo or_s_259.npy
# Se encontró el archivo or_s_260.npy
# Se encontró el archivo or_s_261.npy
# Se encontró el archivo or_s_262.npy
# Se encontró el archivo or_s_263.npy
# Se encontró el archivo or_s_264.npy
# Se encontró el archivo or_s_265.npy
# Se encontró el archivo or_s_266.npy
# Se encontró el archivo or_s_267.npy
# Se encontró el archivo or_s_268.npy
# Se encontró el archivo or_s_269.npy
# Se encontró el archivo or_s_270.npy
# Se encontró el archivo or_s_271.npy
# Se encontró el archivo or_s_272.npy
# Se encontró el archivo or_s_273.npy
# Se encontró el archivo or_s_274.npy
# Se encontró el archivo or_s_275.npy
# Se encontró el archivo or_s_276.npy
# Se encontró el archivo or_s_277.npy
# Se encontró el archivo or_s_278.npy
# Se encontró el archivo or_s_279.npy
# Se encontró el archivo or_s_280.npy
# Se encontró el archivo or_s_281.npy
# Se encontró el archivo or_s_282.npy
# Se encontró el archivo or_s_283.npy
# Se encontró el archivo or_s_284.npy
# Se encontró el archivo or_s_285.npy
# Se encontró el archivo or_s_286.npy
# Se encontró el archivo or_s_287.npy
# Se encontró el archivo or_s_288.npy
# Se encontró el archivo or_s_289.npy
# Se encontró el archivo or_s_290.npy
# Se encontró el archivo or_s_291.npy
# Se encontró el archivo or_s_292.npy
# Se encontró el archivo or_s_293.npy
# Se encontró el archivo or_s_294.npy
# Se encontró el archivo or_s_295.npy
# Se encontró el archivo or_s_296.npy
# Se encontró el archivo or_s_297.npy
# Se encontró el archivo or_s_298.npy
# Se encontró el archivo or_s_299.npy
# Se encontró el archivo or_s_300.npy
# Se encontró el archivo or_s_301.npy
# Se encontró el archivo or_s_302.npy
# Se encontró el archivo or_s_303.npy
# Se encontró el archivo or_s_304.npy
# Se encontró el archivo or_s_305.npy
# Se encontró el archivo or_s_306.npy
# Se encontró el archivo or_s_307.npy
# Se encontró el archivo or_s_308.npy
# Se encontró el archivo or_s_309.npy
# Se encontró el archivo or_s_310.npy
# Se encontró el archivo or_s_311.npy
# Se encontró el archivo or_s_312.npy
# Se encontró el archivo or_s_313.npy
# Se encontró el archivo or_s_314.npy
# Se encontró el archivo or_s_315.npy
# Se encontró el archivo or_s_316.npy
# Se encontró el archivo or_s_317.npy
# Se encontró el archivo or_s_318.npy
# Se encontró el archivo or_s_319.npy
# Se encontró el archivo or_s_320.npy
# Se encontró el archivo or_s_321.npy
# Se encontró el archivo or_s_322.npy
# Se encontró el archivo or_s_323.npy
# Se encontró el archivo or_s_324.npy
# Se encontró el archivo or_s_325.npy
# Se encontró el archivo or_s_326.npy
# Se encontró el archivo or_s_327.npy
# Se encontró el archivo or_s_328.npy
# Se encontró el archivo or_s_329.npy
# Se encontró el archivo or_s_330.npy
# Se encontró el archivo or_s_331.npy
# Se encontró el archivo or_s_332.npy
# Se encontró el archivo or_s_333.npy
# Se encontró el archivo or_s_334.npy
# Se encontró el archivo or_s_335.npy
# Se encontró el archivo or_s_336.npy
# Se encontró el archivo or_s_337.npy
# Se encontró el archivo or_s_338.npy
# Se encontró el archivo or_s_339.npy
# Se encontró el archivo or_s_340.npy
# Se encontró el archivo or_s_341.npy
# Se encontró el archivo or_s_342.npy
# Se encontró el archivo or_s_343.npy
# Se encontró el archivo or_s_344.npy
# Se encontró el archivo or_s_345.npy
# Se encontró el archivo or_s_346.npy
# Se encontró el archivo or_s_347.npy
# Se encontró el archivo or_s_348.npy
# Se encontró el archivo or_s_349.npy
# Se encontró el archivo or_s_350.npy
# Se encontró el archivo or_s_351.npy
# Se encontró el archivo or_s_352.npy
# Se encontró el archivo or_s_353.npy
# Se encontró el archivo or_s_354.npy
# Se encontró el archivo or_s_355.npy
# Se encontró el archivo or_s_356.npy
# Se encontró el archivo or_s_357.npy
# Se encontró el archivo or_s_358.npy
# Se encontró el archivo or_s_359.npy
# Se encontró el archivo or_s_360.npy
# Se encontró el archivo or_s_361.npy
# Se encontró el archivo or_s_362.npy
# Se encontró el archivo or_s_363.npy
# Se encontró el archivo or_s_364.npy
# Se encontró el archivo or_s_365.npy
# Se encontró el archivo or_s_366.npy
# Se encontró el archivo or_s_367.npy
# Se encontró el archivo or_s_368.npy
# Se encontró el archivo or_s_369.npy
# Se encontró el archivo or_s_370.npy
# Se encontró el archivo or_s_371.npy
# Se encontró el archivo or_s_372.npy
# Se encontró el archivo or_s_373.npy
# Se encontró el archivo or_s_374.npy
# Se encontró el archivo or_s_375.npy
# Se encontró el archivo or_s_376.npy
# Se encontró el archivo or_s_377.npy
# Se encontró el archivo or_s_378.npy
# Se encontró el archivo or_s_379.npy
# Se encontró el archivo or_s_380.npy
# Se encontró el archivo or_s_381.npy
# Se encontró el archivo or_s_382.npy
# Se encontró el archivo or_s_383.npy
# Se encontró el archivo or_s_384.npy
# Se encontró el archivo or_s_385.npy
# Se encontró el archivo or_s_386.npy
# Se encontró el archivo or_s_387.npy
# Se encontró el archivo or_s_388.npy
# Se encontró el archivo or_s_389.npy
# Se encontró el archivo or_s_390.npy
# Se encontró el archivo or_s_391.npy
# Se encontró el archivo or_s_392.npy
# Se encontró el archivo or_s_393.npy
# Se encontró el archivo or_s_394.npy
# Se encontró el archivo or_s_395.npy
# Se encontró el archivo or_s_396.npy
# Se encontró el archivo or_s_397.npy
# Se encontró el archivo or_s_398.npy
# Se encontró el archivo or_s_399.npy
# Se encontró el archivo or_s_400.npy
# Se encontró el archivo or_s_401.npy
# Se encontró el archivo or_s_402.npy
# Se encontró el archivo or_s_403.npy
# Se encontró el archivo or_s_404.npy
# Se encontró el archivo or_s_405.npy
# Se encontró el archivo or_s_406.npy
# Se encontró el archivo or_s_407.npy
# Se encontró el archivo or_s_408.npy
# Se encontró el archivo or_s_409.npy
# Se encontró el archivo or_s_410.npy
# Se encontró el archivo or_s_411.npy
# Se encontró el archivo or_s_412.npy
# Se encontró el archivo or_s_413.npy
# Se encontró el archivo or_s_414.npy
# Se encontró el archivo or_s_415.npy
# Se encontró el archivo or_s_416.npy
# Se encontró el archivo or_s_417.npy
# Se encontró el archivo or_s_418.npy
# Se encontró el archivo or_s_419.npy
# Se encontró el archivo or_s_420.npy
# Se encontró el archivo or_s_421.npy
# Se encontró el archivo or_s_422.npy
# Se encontró el archivo or_s_423.npy
# Se encontró el archivo or_s_424.npy
# Se encontró el archivo or_s_425.npy
# Se encontró el archivo or_s_426.npy
# Se encontró el archivo or_s_427.npy
# Se encontró el archivo or_s_428.npy
# Se encontró el archivo or_s_429.npy
# Se encontró el archivo or_s_430.npy
# Se encontró el archivo or_s_431.npy
# Se encontró el archivo or_s_432.npy
# Se encontró el archivo or_s_433.npy
# Se encontró el archivo or_s_434.npy
# Se encontró el archivo or_s_435.npy
# Se encontró el archivo or_s_436.npy
# Se encontró el archivo or_s_437.npy
# Se encontró el archivo or_s_438.npy
# Se encontró el archivo or_s_439.npy
# Se encontró el archivo or_s_440.npy
# Se encontró el archivo or_s_441.npy
# Se encontró el archivo or_s_442.npy
# Se encontró el archivo or_s_443.npy
# Se encontró el archivo or_s_444.npy
# Se encontró el archivo or_s_445.npy
# Se encontró el archivo or_s_446.npy
# Se encontró el archivo or_s_447.npy
# Se encontró el archivo or_s_448.npy
# Se encontró el archivo or_s_449.npy
# Se encontró el archivo or_s_450.npy
# Se encontró el archivo or_s_451.npy
# Se encontró el archivo or_s_452.npy
# Se encontró el archivo or_s_453.npy
# Se encontró el archivo or_s_454.npy
# Se encontró el archivo or_s_455.npy
# Se encontró el archivo or_s_456.npy
# Se encontró el archivo or_s_457.npy
# Se encontró el archivo or_s_458.npy
# Se encontró el archivo or_s_459.npy
# Se encontró el archivo or_s_460.npy
# Se encontró el archivo or_s_461.npy
# Se encontró el archivo or_s_462.npy
# Se encontró el archivo or_s_463.npy
# Se encontró el archivo or_s_464.npy
# Se encontró el archivo or_s_465.npy
# Se encontró el archivo or_s_466.npy
# Se encontró el archivo or_s_467.npy
# Se encontró el archivo or_s_468.npy
# Se encontró el archivo or_s_469.npy
# Se encontró el archivo or_s_470.npy
# Se encontró el archivo or_s_471.npy
# Se encontró el archivo or_s_472.npy
# Se encontró el archivo or_s_473.npy
# Se encontró el archivo or_s_474.npy
# Se encontró el archivo or_s_475.npy
# Se encontró el archivo or_s_476.npy
# Se encontró el archivo or_s_477.npy
# Se encontró el archivo or_s_478.npy
# Se encontró el archivo or_s_479.npy
# Se encontró el archivo or_s_480.npy
# Se encontró el archivo or_s_481.npy
# Se encontró el archivo or_s_482.npy
# Se encontró el archivo or_s_483.npy
# Se encontró el archivo or_s_484.npy
# Se encontró el archivo or_s_485.npy
# Se encontró el archivo or_s_486.npy
# Se encontró el archivo or_s_487.npy
# Se encontró el archivo or_s_488.npy
# Se encontró el archivo or_s_489.npy
# Se encontró el archivo or_s_490.npy
# Se encontró el archivo or_s_491.npy
# Se encontró el archivo or_s_492.npy
# Se encontró el archivo or_s_493.npy
# Se encontró el archivo or_s_494.npy
# Se encontró el archivo or_s_495.npy
# Se encontró el archivo or_s_496.npy
# Se encontró el archivo or_s_497.npy
# Se encontró el archivo or_s_498.npy
# Se encontró el archivo or_s_499.npy
# Se encontró el archivo or_s_500.npy
# Se encontró el archivo or_s_501.npy
# Se encontró el archivo or_s_502.npy
# Se encontró el archivo or_s_503.npy
# Se encontró el archivo or_s_504.npy
# Se encontró el archivo or_s_505.npy
# Se encontró el archivo or_s_506.npy
# Se encontró el archivo or_s_507.npy
# Se encontró el archivo or_s_508.npy
# Se encontró el archivo or_s_509.npy
# Se encontró el archivo or_s_510.npy
# Se encontró el archivo or_s_511.npy
# Se encontró el archivo or_s_512.npy
# Se encontró el archivo or_s_513.npy
# Se encontró el archivo or_s_514.npy
# Se encontró el archivo or_s_515.npy
# Se encontró el archivo or_s_516.npy
# Se encontró el archivo or_s_517.npy
# Se encontró el archivo or_s_518.npy
# Se encontró el archivo or_s_519.npy
# Se encontró el archivo or_s_520.npy
# Se encontró el archivo or_s_521.npy
# Se encontró el archivo or_s_522.npy
# Se encontró el archivo or_s_523.npy
# Se encontró el archivo or_s_524.npy
# Se encontró el archivo or_s_525.npy
# Se encontró el archivo or_s_526.npy
# Se encontró el archivo or_s_527.npy
# Se encontró el archivo or_s_528.npy
# Se encontró el archivo or_s_529.npy
# Se encontró el archivo or_s_530.npy
# Se encontró el archivo or_s_531.npy
# Se encontró el archivo or_s_532.npy
# Se encontró el archivo or_s_533.npy
# Se encontró el archivo or_s_534.npy
# Se encontró el archivo or_s_535.npy
# Se encontró el archivo or_s_536.npy
# Se encontró el archivo or_s_537.npy
# Se encontró el archivo or_s_538.npy
# Se encontró el archivo or_s_539.npy
# Se encontró el archivo or_s_540.npy
# Se encontró el archivo or_s_541.npy
# Se encontró el archivo or_s_542.npy
# Se encontró el archivo or_s_543.npy
# Se encontró el archivo or_s_544.npy
# Se encontró el archivo or_s_545.npy
# Se encontró el archivo or_s_546.npy
# Se encontró el archivo or_s_547.npy
# Se encontró el archivo or_s_548.npy
# Se encontró el archivo or_s_549.npy
# Se encontró el archivo or_s_550.npy
# Se encontró el archivo or_s_551.npy
# Se encontró el archivo or_s_552.npy
# Se encontró el archivo or_s_553.npy
# Se encontró el archivo or_s_554.npy
# Se encontró el archivo or_s_555.npy
# Se encontró el archivo or_s_556.npy
# Se encontró el archivo or_s_557.npy
# Se encontró el archivo or_s_558.npy
# Se encontró el archivo or_s_559.npy
# Se encontró el archivo or_s_560.npy
# Se encontró el archivo or_s_561.npy
# Se encontró el archivo or_s_562.npy
# Se encontró el archivo or_s_563.npy
# Se encontró el archivo or_s_564.npy
# Se encontró el archivo or_s_565.npy
# Se encontró el archivo or_s_566.npy
# Se encontró el archivo or_s_567.npy
# Se encontró el archivo or_s_568.npy
# Se encontró el archivo or_s_569.npy
# Se encontró el archivo or_s_570.npy
# Se encontró el archivo or_s_571.npy
# Se encontró el archivo or_s_572.npy
# Se encontró el archivo or_s_573.npy
# Se encontró el archivo or_s_574.npy
# Se encontró el archivo or_s_575.npy
# Se encontró el archivo or_s_576.npy
# Se encontró el archivo or_s_577.npy
# Se encontró el archivo or_s_578.npy
# Se encontró el archivo or_s_579.npy
# Se encontró el archivo or_s_580.npy
# Se encontró el archivo or_s_581.npy
# Se encontró el archivo or_s_582.npy
# Se encontró el archivo or_s_583.npy
# Se encontró el archivo or_s_584.npy
# Se encontró el archivo or_s_585.npy
# Se encontró el archivo or_s_586.npy
# Se encontró el archivo or_s_587.npy
# Se encontró el archivo or_s_588.npy
# Se encontró el archivo or_s_589.npy
# Se encontró el archivo or_s_590.npy
# Se encontró el archivo or_s_591.npy
# Se encontró el archivo or_s_592.npy
# Se encontró el archivo or_s_593.npy
# Se encontró el archivo or_s_594.npy
# Se encontró el archivo or_s_595.npy
# Se encontró el archivo or_s_596.npy
# Se encontró el archivo or_s_597.npy
# Se encontró el archivo or_s_598.npy
# Se encontró el archivo or_s_599.npy
# Se encontró el archivo or_s_600.npy
# Se encontró el archivo or_s_601.npy
# Se encontró el archivo or_s_602.npy
# Se encontró el archivo or_s_603.npy
# Se encontró el archivo or_s_604.npy
# Se encontró el archivo or_s_605.npy
# Se encontró el archivo or_s_606.npy
# Se encontró el archivo or_s_607.npy
# Se encontró el archivo or_s_608.npy
# Se encontró el archivo or_s_609.npy
# Se encontró el archivo or_s_610.npy
# Se encontró el archivo or_s_611.npy
# Se encontró el archivo or_s_612.npy
# Se encontró el archivo or_s_613.npy
# Se encontró el archivo or_s_614.npy
# Se encontró el archivo or_s_615.npy
# Se encontró el archivo or_s_616.npy
# Se encontró el archivo or_s_617.npy
# Se encontró el archivo or_s_618.npy
# Se encontró el archivo or_s_619.npy
# Se encontró el archivo or_s_620.npy
# Se encontró el archivo or_s_621.npy
# Se encontró el archivo or_s_622.npy
# Se encontró el archivo or_s_623.npy
# Se encontró el archivo or_s_624.npy
# Se encontró el archivo or_s_625.npy
# Se encontró el archivo or_s_626.npy
# Se encontró el archivo or_s_627.npy
# Se encontró el archivo or_s_628.npy
# Se encontró el archivo or_s_629.npy
# Se encontró el archivo or_s_630.npy
# Se encontró el archivo or_s_631.npy
# Se encontró el archivo or_s_632.npy
# Se encontró el archivo or_s_633.npy
# Se encontró el archivo or_s_634.npy
# Se encontró el archivo or_s_635.npy
# Se encontró el archivo or_s_636.npy
# Se encontró el archivo or_s_637.npy
# Se encontró el archivo or_s_638.npy
# Se encontró el archivo or_s_639.npy
# Se encontró el archivo or_s_640.npy
# Se encontró el archivo or_s_641.npy
# Se encontró el archivo or_s_642.npy
# Se encontró el archivo or_s_643.npy
# Se encontró el archivo or_s_644.npy
# Se encontró el archivo or_s_645.npy
# Se encontró el archivo or_s_646.npy
# Se encontró el archivo or_s_647.npy
# Se encontró el archivo or_s_648.npy
# Se encontró el archivo or_s_649.npy
# Se encontró el archivo or_s_650.npy
# Se encontró el archivo or_s_651.npy
# Se encontró el archivo or_s_652.npy
# Se encontró el archivo or_s_653.npy
# Se encontró el archivo or_s_654.npy
# Se encontró el archivo or_s_655.npy
# Se encontró el archivo or_s_656.npy
# Se encontró el archivo or_s_657.npy
# Se encontró el archivo or_s_658.npy
# Se encontró el archivo or_s_659.npy
# Se encontró el archivo or_s_660.npy
# Se encontró el archivo or_s_661.npy
# Se encontró el archivo or_s_662.npy
# Se encontró el archivo or_s_663.npy
# Se encontró el archivo or_s_664.npy
# Se encontró el archivo or_s_665.npy
# Se encontró el archivo or_s_666.npy
# Se encontró el archivo or_s_667.npy
# Se encontró el archivo or_s_668.npy
# Se encontró el archivo or_s_669.npy
# Se encontró el archivo or_s_670.npy
# Se encontró el archivo or_s_671.npy
# Se encontró el archivo or_s_672.npy
# Se encontró el archivo or_s_673.npy
# Se encontró el archivo or_s_674.npy
# Se encontró el archivo or_s_675.npy
# Se encontró el archivo or_s_676.npy
# Se encontró el archivo or_s_677.npy
# Se encontró el archivo or_s_678.npy
# Se encontró el archivo or_s_679.npy
# Se encontró el archivo or_s_680.npy
# Se encontró el archivo or_s_681.npy
# Se encontró el archivo or_s_682.npy
# Se encontró el archivo or_s_683.npy
# Se encontró el archivo or_s_684.npy
# Se encontró el archivo or_s_685.npy
# Se encontró el archivo or_s_686.npy
# Se encontró el archivo or_s_687.npy
# Se encontró el archivo or_s_688.npy
# Se encontró el archivo or_s_689.npy
# Se encontró el archivo or_s_690.npy
# Se encontró el archivo or_s_691.npy
# Se encontró el archivo or_s_692.npy
# Se encontró el archivo or_s_693.npy
# Se encontró el archivo or_s_694.npy
# Se encontró el archivo or_s_695.npy
# Se encontró el archivo or_s_696.npy
# Se encontró el archivo or_s_697.npy
# Se encontró el archivo or_s_698.npy
# Se encontró el archivo or_s_699.npy
# Se encontró el archivo or_s_700.npy
# Se encontró el archivo or_s_701.npy
# Se encontró el archivo or_s_702.npy
# Se encontró el archivo or_s_703.npy
# Se encontró el archivo or_s_704.npy
# Se encontró el archivo or_s_705.npy
# Se encontró el archivo or_s_706.npy
# Se encontró el archivo or_s_707.npy
# Se encontró el archivo or_s_708.npy
# Se encontró el archivo or_s_709.npy
# Se encontró el archivo or_s_710.npy
# Se encontró el archivo or_s_711.npy
# Se encontró el archivo or_s_712.npy
# Se encontró el archivo or_s_713.npy
# Se encontró el archivo or_s_714.npy
# Se encontró el archivo or_s_715.npy
# Se encontró el archivo or_s_716.npy
# Se encontró el archivo or_s_717.npy
# Se encontró el archivo or_s_718.npy
# Se encontró el archivo or_s_719.npy
# Se encontró el archivo or_s_720.npy
# Se encontró el archivo or_s_721.npy
# Se encontró el archivo or_s_722.npy
# Se encontró el archivo or_s_723.npy
# Se encontró el archivo or_s_724.npy
# Se encontró el archivo or_s_725.npy
# Se encontró el archivo or_s_726.npy
# Se encontró el archivo or_s_727.npy
# Se encontró el archivo or_s_728.npy
# Se encontró el archivo or_s_729.npy
# Se encontró el archivo or_s_730.npy
# Se encontró el archivo or_s_731.npy
# Se encontró el archivo or_s_732.npy
# Se encontró el archivo or_s_733.npy
# Se encontró el archivo or_s_734.npy
# Se encontró el archivo or_s_735.npy
# Se encontró el archivo or_s_736.npy
# Se encontró el archivo or_s_737.npy
# Se encontró el archivo or_s_738.npy
# Se encontró el archivo or_s_739.npy
# Se encontró el archivo or_s_740.npy
# Se encontró el archivo or_s_741.npy
# Se encontró el archivo or_s_742.npy
# Se encontró el archivo or_s_743.npy
# Se encontró el archivo or_s_744.npy
# Se encontró el archivo or_s_745.npy
# Se encontró el archivo or_s_746.npy
# Se encontró el archivo or_s_747.npy
# Se encontró el archivo or_s_748.npy
# Se encontró el archivo or_s_749.npy
# Se encontró el archivo or_s_750.npy
# Se encontró el archivo or_s_751.npy
# Se encontró el archivo or_s_752.npy
# Se encontró el archivo or_s_753.npy
# Se encontró el archivo or_s_754.npy
# Se encontró el archivo or_s_755.npy
# Se encontró el archivo or_s_756.npy
# Se encontró el archivo or_s_757.npy
# Se encontró el archivo or_s_758.npy
# Se encontró el archivo or_s_759.npy
# Se encontró el archivo or_s_760.npy
# Se encontró el archivo or_s_761.npy
# Se encontró el archivo or_s_762.npy
# Se encontró el archivo or_s_763.npy
# Se encontró el archivo or_s_764.npy
# Se encontró el archivo or_s_765.npy
# Se encontró el archivo or_s_766.npy
# Se encontró el archivo or_s_767.npy
# Se encontró el archivo or_s_768.npy
# Se encontró el archivo or_s_769.npy
# Se encontró el archivo or_s_770.npy
# Se encontró el archivo or_s_771.npy
# Se encontró el archivo or_s_772.npy
# Se encontró el archivo or_s_773.npy
# Se encontró el archivo or_s_774.npy
# Se encontró el archivo or_s_775.npy
# Se encontró el archivo or_s_776.npy
# Se encontró el archivo or_s_777.npy
# Se encontró el archivo or_s_778.npy
# Se encontró el archivo or_s_779.npy
# Se encontró el archivo or_s_780.npy
# Se encontró el archivo or_s_781.npy
# Se encontró el archivo or_s_782.npy
# Se encontró el archivo or_s_783.npy
# Se encontró el archivo or_s_784.npy
# Se encontró el archivo or_s_785.npy
# Se encontró el archivo or_s_786.npy
# Se encontró el archivo or_s_787.npy
# Se encontró el archivo or_s_788.npy
# Se encontró el archivo or_s_789.npy
# Se encontró el archivo or_s_790.npy
# Se encontró el archivo or_s_791.npy
# Se encontró el archivo or_s_792.npy
# Se encontró el archivo or_s_793.npy
# Se encontró el archivo or_s_794.npy
# Se encontró el archivo or_s_795.npy
# Se encontró el archivo or_s_796.npy
# Se encontró el archivo or_s_797.npy
# Se encontró el archivo or_s_798.npy
# Se encontró el archivo or_s_799.npy
# Se encontró el archivo or_s_800.npy
# Se encontró el archivo or_s_801.npy
# Se encontró el archivo or_s_802.npy
# Se encontró el archivo or_s_803.npy
# Se encontró el archivo or_s_804.npy
# Se encontró el archivo or_s_805.npy
# Se encontró el archivo or_s_806.npy
# Se encontró el archivo or_s_807.npy
# Se encontró el archivo or_s_808.npy
# Se encontró el archivo or_s_809.npy
# Se encontró el archivo or_s_810.npy
# Se encontró el archivo or_s_811.npy
# Se encontró el archivo or_s_812.npy
# Se encontró el archivo or_s_813.npy
# Se encontró el archivo or_s_814.npy
# Se encontró el archivo or_s_815.npy
# Se encontró el archivo or_s_816.npy
# Se encontró el archivo or_s_817.npy
# Se encontró el archivo or_s_818.npy
# Se encontró el archivo or_s_819.npy
# Se encontró el archivo or_s_820.npy
# Se encontró el archivo or_s_821.npy
# Se encontró el archivo or_s_822.npy
# Se encontró el archivo or_s_823.npy
# Se encontró el archivo or_s_824.npy
# Se encontró el archivo or_s_825.npy
# Se encontró el archivo or_s_826.npy
# Se encontró el archivo or_s_827.npy
# Se encontró el archivo or_s_828.npy
# Se encontró el archivo or_s_829.npy
# Se encontró el archivo or_s_830.npy
# Se encontró el archivo or_s_831.npy
# Se encontró el archivo or_s_832.npy
# Se encontró el archivo or_s_833.npy
# Se encontró el archivo or_s_834.npy
# Se encontró el archivo or_s_835.npy
# Se encontró el archivo or_s_836.npy
# Se encontró el archivo or_s_837.npy
# Se encontró el archivo or_s_838.npy
# Se encontró el archivo or_s_839.npy
# Se encontró el archivo or_s_840.npy
# Se encontró el archivo or_s_841.npy
# Se encontró el archivo or_s_842.npy
# Se encontró el archivo or_s_843.npy
# Se encontró el archivo or_s_844.npy
# Se encontró el archivo or_s_845.npy
# Se encontró el archivo or_s_846.npy
# Se encontró el archivo or_s_847.npy
# Se encontró el archivo or_s_848.npy
# Se encontró el archivo or_s_849.npy
# Se encontró el archivo or_s_850.npy
# Se encontró el archivo or_s_851.npy
# Se encontró el archivo or_s_852.npy
# Se encontró el archivo or_s_853.npy
# Se encontró el archivo or_s_854.npy
# Se encontró el archivo or_s_855.npy
# Se encontró el archivo or_s_856.npy
# Se encontró el archivo or_s_857.npy
# Se encontró el archivo or_s_858.npy
# Se encontró el archivo or_s_859.npy
# Se encontró el archivo or_s_860.npy
# Se encontró el archivo or_s_861.npy
# Se encontró el archivo or_s_862.npy
# Se encontró el archivo or_s_863.npy
# Se encontró el archivo or_s_864.npy
# Se encontró el archivo or_s_865.npy
# Se encontró el archivo or_s_866.npy
# Se encontró el archivo or_s_867.npy
# Se encontró el archivo or_s_868.npy
# Se encontró el archivo or_s_869.npy
# Se encontró el archivo or_s_870.npy
# Se encontró el archivo or_s_871.npy
# Se encontró el archivo or_s_872.npy
# Se encontró el archivo or_s_873.npy
# Se encontró el archivo or_s_874.npy
# Se encontró el archivo or_s_875.npy
# Se encontró el archivo or_s_876.npy
# Se encontró el archivo or_s_877.npy
# Se encontró el archivo or_s_878.npy
# Se encontró el archivo or_s_879.npy
# Se encontró el archivo or_s_880.npy
# Se encontró el archivo or_s_881.npy
# Se encontró el archivo or_s_882.npy
# Se encontró el archivo or_s_883.npy
# Se encontró el archivo or_s_884.npy
# Se encontró el archivo or_s_885.npy
# Se encontró el archivo or_s_886.npy
# Se encontró el archivo or_s_887.npy
# Se encontró el archivo or_s_888.npy
# Se encontró el archivo or_s_889.npy
# Se encontró el archivo or_s_890.npy
# Se encontró el archivo or_s_891.npy
# Se encontró el archivo or_s_892.npy
# Se encontró el archivo or_s_893.npy
# Se encontró el archivo or_s_894.npy
# Se encontró el archivo or_s_895.npy
# Se encontró el archivo or_s_896.npy
# Se encontró el archivo or_s_897.npy
# Se encontró el archivo or_s_898.npy
# Se encontró el archivo or_s_899.npy
# Se encontró el archivo or_s_900.npy
# Se encontró el archivo or_s_901.npy
# Se encontró el archivo or_s_902.npy
# Se encontró el archivo or_s_903.npy
# Se encontró el archivo or_s_904.npy
# Se encontró el archivo or_s_905.npy
# Se encontró el archivo or_s_906.npy
# Se encontró el archivo or_s_907.npy
# Se encontró el archivo or_s_908.npy
# Se encontró el archivo or_s_909.npy
# Se encontró el archivo or_s_910.npy
# Se encontró el archivo or_s_911.npy
# Se encontró el archivo or_s_912.npy
# Se encontró el archivo or_s_913.npy
# Se encontró el archivo or_s_914.npy
# Se encontró el archivo or_s_915.npy
# Se encontró el archivo or_s_916.npy
# Se encontró el archivo or_s_917.npy
# Se encontró el archivo or_s_918.npy
# Se encontró el archivo or_s_919.npy
# Se encontró el archivo or_s_920.npy
# Se encontró el archivo or_s_921.npy
# Se encontró el archivo or_s_922.npy
# Se encontró el archivo or_s_923.npy
# Se encontró el archivo or_s_924.npy
# Se encontró el archivo or_s_925.npy
# Se encontró el archivo or_s_926.npy
# Se encontró el archivo or_s_927.npy
# Se encontró el archivo or_s_928.npy
# Se encontró el archivo or_s_929.npy
# Se encontró el archivo or_s_930.npy
# Se encontró el archivo or_s_931.npy
# Se encontró el archivo or_s_932.npy
# Se encontró el archivo or_s_933.npy
# Se encontró el archivo or_s_934.npy
# Se encontró el archivo or_s_935.npy
# Se encontró el archivo or_s_936.npy
# Se encontró el archivo or_s_937.npy
# Se encontró el archivo or_s_938.npy
# Se encontró el archivo or_s_939.npy
# Se encontró el archivo or_s_940.npy
# Se encontró el archivo or_s_941.npy
# Se encontró el archivo or_s_942.npy
# Se encontró el archivo or_s_943.npy
# Se encontró el archivo or_s_944.npy
# Se encontró el archivo or_s_945.npy
# Se encontró el archivo or_s_946.npy
# Se encontró el archivo or_s_947.npy
# Se encontró el archivo or_s_948.npy
# Se encontró el archivo or_s_949.npy
# Se encontró el archivo or_s_950.npy
# Se encontró el archivo or_s_951.npy
# Se encontró el archivo or_s_952.npy
# Se encontró el archivo or_s_953.npy
# Se encontró el archivo or_s_954.npy
# Se encontró el archivo or_s_955.npy
# Se encontró el archivo or_s_956.npy
# Se encontró el archivo or_s_957.npy
# Se encontró el archivo or_s_958.npy
# Se encontró el archivo or_s_959.npy
# Se encontró el archivo or_s_960.npy
# Se encontró el archivo or_s_961.npy
# Se encontró el archivo or_s_962.npy
# Se encontró el archivo or_s_963.npy
# Se encontró el archivo or_s_964.npy
# Se encontró el archivo or_s_965.npy
# Se encontró el archivo or_s_966.npy
# Se encontró el archivo or_s_967.npy
# Se encontró el archivo or_s_968.npy
# Se encontró el archivo or_s_969.npy
# Se encontró el archivo or_s_970.npy
# Se encontró el archivo or_s_971.npy
# Se encontró el archivo or_s_972.npy
# Se encontró el archivo or_s_973.npy
# Se encontró el archivo or_s_974.npy
# Se encontró el archivo or_s_975.npy
# Se encontró el archivo or_s_976.npy
# Se encontró el archivo or_s_977.npy
# Se encontró el archivo or_s_978.npy
# Se encontró el archivo or_s_979.npy
# Se encontró el archivo or_s_980.npy
# Se encontró el archivo or_s_981.npy
# Se encontró el archivo or_s_982.npy
# Se encontró el archivo or_s_983.npy
# Se encontró el archivo or_s_984.npy
# Se encontró el archivo or_s_985.npy
# Se encontró el archivo or_s_986.npy
# Se encontró el archivo or_s_987.npy
# Se encontró el archivo or_s_988.npy
# Se encontró el archivo or_s_989.npy
# Se encontró el archivo or_s_990.npy
# Se encontró el archivo or_s_991.npy
# Se encontró el archivo or_s_992.npy
# Se encontró el archivo or_s_993.npy
# Se encontró el archivo or_s_994.npy
# Se encontró el archivo or_s_995.npy
# Se encontró el archivo or_s_996.npy
# Se encontró el archivo or_s_997.npy
# Se encontró el archivo or_s_998.npy
# Se encontró el archivo or_s_999.npy
# Se encontró el archivo or_s_1000.npy
# Se encontró el archivo or_s_1001.npy
# Se encontró el archivo or_s_1002.npy
# Se encontró el archivo or_s_1003.npy
# Se encontró el archivo or_s_1004.npy
# Se encontró el archivo or_s_1005.npy
# Se encontró el archivo or_s_1006.npy
# Se encontró el archivo or_s_1007.npy
# Se encontró el archivo or_s_1008.npy
# Se encontró el archivo or_s_1009.npy
# Se encontró el archivo or_s_1010.npy
# Se encontró el archivo or_s_1011.npy
# Se encontró el archivo or_s_1012.npy
# Se encontró el archivo or_s_1013.npy
# Se encontró el archivo or_s_1014.npy
# Se encontró el archivo or_s_1015.npy
# Se encontró el archivo or_s_1016.npy
# Se encontró el archivo or_s_1017.npy
# Se encontró el archivo or_s_1018.npy
# Se encontró el archivo or_s_1019.npy
# Se encontró el archivo or_s_1020.npy
# Se encontró el archivo or_s_1021.npy
# Se encontró el archivo or_s_1022.npy
# Se encontró el archivo or_s_1023.npy
# Se encontró el archivo or_s_1024.npy
# Se encontró el archivo or_s_1025.npy
# Se encontró el archivo or_s_1026.npy
# Se encontró el archivo or_s_1027.npy
# Se encontró el archivo or_s_1028.npy
# Se encontró el archivo or_s_1029.npy
# Se encontró el archivo or_s_1030.npy
# Se encontró el archivo or_s_1031.npy
# Se encontró el archivo or_s_1032.npy
# Se encontró el archivo or_s_1033.npy
# Se encontró el archivo or_s_1034.npy
# Se encontró el archivo or_s_1035.npy
# Se encontró el archivo or_s_1036.npy
# Se encontró el archivo or_s_1037.npy
# Se encontró el archivo or_s_1038.npy
# Se encontró el archivo or_s_1039.npy
# Se encontró el archivo or_s_1040.npy
# Se encontró el archivo or_s_1041.npy
# Se encontró el archivo or_s_1042.npy
# Se encontró el archivo or_s_1043.npy
# Se encontró el archivo or_s_1044.npy
# Se encontró el archivo or_s_1045.npy
# Se encontró el archivo or_s_1046.npy
# Se encontró el archivo or_s_1047.npy
# Se encontró el archivo or_s_1048.npy
# Se encontró el archivo or_s_1049.npy
# Se encontró el archivo or_s_1050.npy
# Se encontró el archivo or_s_1051.npy
# Se encontró el archivo or_s_1052.npy
# Se encontró el archivo or_s_1053.npy
# Se encontró el archivo or_s_1054.npy
# Se encontró el archivo or_s_1055.npy
# Se encontró el archivo or_s_1056.npy
# Se encontró el archivo or_s_1057.npy
# Se encontró el archivo or_s_1058.npy
# Se encontró el archivo or_s_1059.npy
# Se encontró el archivo or_s_1060.npy
# Se encontró el archivo or_s_1061.npy
# Se encontró el archivo or_s_1062.npy
# Se encontró el archivo or_s_1063.npy
# Se encontró el archivo or_s_1064.npy
# Se encontró el archivo or_s_1065.npy
# Se encontró el archivo or_s_1066.npy
# Se encontró el archivo or_s_1067.npy
# Se encontró el archivo or_s_1068.npy
# Se encontró el archivo or_s_1069.npy
# Se encontró el archivo or_s_1070.npy
# Se encontró el archivo or_s_1071.npy
# Se encontró el archivo or_s_1072.npy
# Se encontró el archivo or_s_1073.npy
# Se encontró el archivo or_s_1074.npy
# Se encontró el archivo or_s_1075.npy
# Se encontró el archivo or_s_1076.npy
# Se encontró el archivo or_s_1077.npy
# Se encontró el archivo or_s_1078.npy
# Se encontró el archivo or_s_1079.npy
# Se encontró el archivo or_s_1080.npy
# Se encontró el archivo or_s_1081.npy
# Se encontró el archivo or_s_1082.npy
# Se encontró el archivo or_s_1083.npy
# Se encontró el archivo or_s_1084.npy
# Se encontró el archivo or_s_1085.npy
# Se encontró el archivo or_s_1086.npy
# Se encontró el archivo or_s_1087.npy
# Se encontró el archivo or_s_1088.npy
# Se encontró el archivo or_s_1089.npy
# Se encontró el archivo or_s_1090.npy
# Se encontró el archivo or_s_1091.npy
# Se encontró el archivo or_s_1092.npy
# Se encontró el archivo or_s_1093.npy
# Se encontró el archivo or_s_1094.npy
# Se encontró el archivo or_s_1095.npy
# Se encontró el archivo or_s_1096.npy
# Se encontró el archivo or_s_1097.npy
# Se encontró el archivo or_s_1098.npy
# Se encontró el archivo or_s_1099.npy
# Se encontró el archivo or_s_1100.npy
# Se encontró el archivo or_s_1101.npy
# Se encontró el archivo or_s_1102.npy
# Se encontró el archivo or_s_1103.npy
# Se encontró el archivo or_s_1104.npy
# Se encontró el archivo or_s_1105.npy
# Se encontró el archivo or_s_1106.npy
# Se encontró el archivo or_s_1107.npy
# Se encontró el archivo or_s_1108.npy
# Se encontró el archivo or_s_1109.npy
# Se encontró el archivo or_s_1110.npy
# Se encontró el archivo or_s_1111.npy
# Se encontró el archivo or_s_1112.npy
# Se encontró el archivo or_s_1113.npy
# Se encontró el archivo or_s_1114.npy
# Se encontró el archivo or_s_1115.npy
# Se encontró el archivo or_s_1116.npy
# Se encontró el archivo or_s_1117.npy
# Se encontró el archivo or_s_1118.npy
# Se encontró el archivo or_s_1119.npy
# Se encontró el archivo or_s_1120.npy
# Se encontró el archivo or_s_1121.npy
# Se encontró el archivo or_s_1122.npy
# Se encontró el archivo or_s_1123.npy
# Se encontró el archivo or_s_1124.npy
# Se encontró el archivo or_s_1125.npy
# Se encontró el archivo or_s_1126.npy
# Se encontró el archivo or_s_1127.npy
# Se encontró el archivo or_s_1128.npy
# Se encontró el archivo or_s_1129.npy
# Se encontró el archivo or_s_1130.npy
# Se encontró el archivo or_s_1131.npy
# Se encontró el archivo or_s_1132.npy
# Se encontró el archivo or_s_1133.npy
# Se encontró el archivo or_s_1134.npy
# Se encontró el archivo or_s_1135.npy
# Se encontró el archivo or_s_1136.npy
# Se encontró el archivo or_s_1137.npy
# Se encontró el archivo or_s_1138.npy
# Se encontró el archivo or_s_1139.npy
# Se encontró el archivo or_s_1140.npy
# Se encontró el archivo or_s_1141.npy
# Se encontró el archivo or_s_1142.npy
# Se encontró el archivo or_s_1143.npy
# Se encontró el archivo or_s_1144.npy
# Se encontró el archivo or_s_1145.npy
# Se encontró el archivo or_s_1146.npy
# Se encontró el archivo or_s_1147.npy
# Se encontró el archivo or_s_1148.npy
# Se encontró el archivo or_s_1149.npy
# Se encontró el archivo or_s_1150.npy
# Se encontró el archivo or_s_1151.npy
# Se encontró el archivo or_s_1152.npy
# Se encontró el archivo or_s_1153.npy
# Se encontró el archivo or_s_1154.npy
# Se encontró el archivo or_s_1155.npy
# Se encontró el archivo or_s_1156.npy
# Se encontró el archivo or_s_1157.npy
# Se encontró el archivo or_s_1158.npy
# Se encontró el archivo or_s_1159.npy
# Se encontró el archivo or_s_1160.npy
# Se encontró el archivo or_s_1161.npy
# Se encontró el archivo or_s_1162.npy
# Se encontró el archivo or_s_1163.npy
# Se encontró el archivo or_s_1164.npy
# Se encontró el archivo or_s_1165.npy
# Se encontró el archivo or_s_1166.npy
# Se encontró el archivo or_s_1167.npy
# Se encontró el archivo or_s_1168.npy
# Se encontró el archivo or_s_1169.npy
# Se encontró el archivo or_s_1170.npy
# Se encontró el archivo or_s_1171.npy
# Se encontró el archivo or_s_1172.npy
# Se encontró el archivo or_s_1173.npy
# Se encontró el archivo or_s_1174.npy
# Se encontró el archivo or_s_1175.npy
# Se encontró el archivo or_s_1176.npy
# Se encontró el archivo or_s_1177.npy
# Se encontró el archivo or_s_1178.npy
# Se encontró el archivo or_s_1179.npy
# Se encontró el archivo or_s_1180.npy
# Se encontró el archivo or_s_1181.npy
# Se encontró el archivo or_s_1182.npy
# Se encontró el archivo or_s_1183.npy
# Se encontró el archivo or_s_1184.npy
# Se encontró el archivo or_s_1185.npy
# Se encontró el archivo or_s_1186.npy
# Se encontró el archivo or_s_1187.npy
# Se encontró el archivo or_s_1188.npy
# Se encontró el archivo or_s_1189.npy
# Se encontró el archivo or_s_1190.npy
# Se encontró el archivo or_s_1191.npy
# Se encontró el archivo or_s_1192.npy
# Se encontró el archivo or_s_1193.npy
# Se encontró el archivo or_s_1194.npy
# Se encontró el archivo or_s_1195.npy
# Se encontró el archivo or_s_1196.npy
# Se encontró el archivo or_s_1197.npy
# Se encontró el archivo or_s_1198.npy
# Se encontró el archivo or_s_1199.npy
# Se encontró el archivo or_s_1200.npy
# Se encontró el archivo or_s_1201.npy
# Se encontró el archivo or_s_1202.npy
# Se encontró el archivo or_s_1203.npy
# Se encontró el archivo or_s_1204.npy
# Se encontró el archivo or_s_1205.npy
# Se encontró el archivo or_s_1206.npy
# Se encontró el archivo or_s_1207.npy
# Se encontró el archivo or_s_1208.npy
# Se encontró el archivo or_s_1209.npy
# Se encontró el archivo or_s_1210.npy
# Se encontró el archivo or_s_1211.npy
# Se encontró el archivo or_s_1212.npy
# Se encontró el archivo or_s_1213.npy
# Se encontró el archivo or_s_1214.npy
# Se encontró el archivo or_s_1215.npy
# Se encontró el archivo or_s_1216.npy
# Se encontró el archivo or_s_1217.npy
# Se encontró el archivo or_s_1218.npy
# Se encontró el archivo or_s_1219.npy
# Se encontró el archivo or_s_1220.npy
# Se encontró el archivo or_s_1221.npy
# Se encontró el archivo or_s_1222.npy
# Se encontró el archivo or_s_1223.npy
# Se encontró el archivo or_s_1224.npy
# Se encontró el archivo or_s_1225.npy
# Se encontró el archivo or_s_1226.npy
# Se encontró el archivo or_s_1227.npy
# Se encontró el archivo or_s_1228.npy
# Se encontró el archivo or_s_1229.npy
# Se encontró el archivo or_s_1230.npy
# Se encontró el archivo or_s_1231.npy
# Se encontró el archivo or_s_1232.npy
# Se encontró el archivo or_s_1233.npy
# Se encontró el archivo or_s_1234.npy
# Se encontró el archivo or_s_1235.npy
# Se encontró el archivo or_s_1236.npy
# Se encontró el archivo or_s_1237.npy
# Se encontró el archivo or_s_1238.npy
# Se encontró el archivo or_s_1239.npy
# Se encontró el archivo or_s_1240.npy
# Se encontró el archivo or_s_1241.npy
# Se encontró el archivo or_s_1242.npy
# Se encontró el archivo or_s_1243.npy
# Se encontró el archivo or_s_1244.npy
# Se encontró el archivo or_s_1245.npy
# Se encontró el archivo or_s_1246.npy
# Se encontró el archivo or_s_1247.npy
# Se encontró el archivo or_s_1248.npy
# Se encontró el archivo or_s_1249.npy
# Se encontró el archivo or_s_1250.npy
# Se encontró el archivo or_s_1251.npy
# Se encontró el archivo or_s_1252.npy
# Se encontró el archivo or_s_1253.npy
# Se encontró el archivo or_s_1254.npy
# Se encontró el archivo or_s_1255.npy
# Se encontró el archivo or_s_1256.npy
# Se encontró el archivo or_s_1257.npy
# Se encontró el archivo or_s_1258.npy
# Se encontró el archivo or_s_1259.npy
# Se encontró el archivo or_s_1260.npy
# Se encontró el archivo or_s_1261.npy
# Se encontró el archivo or_s_1262.npy
# Se encontró el archivo or_s_1263.npy
# Se encontró el archivo or_s_1264.npy
# Se encontró el archivo or_s_1265.npy
# Se encontró el archivo or_s_1266.npy
# Se encontró el archivo or_s_1267.npy
# Se encontró el archivo or_s_1268.npy
# Se encontró el archivo or_s_1269.npy
# Se encontró el archivo or_s_1270.npy
# Se encontró el archivo or_s_1271.npy
# Se encontró el archivo or_s_1272.npy
# Se encontró el archivo or_s_1273.npy
# Se encontró el archivo or_s_1274.npy
# Se encontró el archivo or_s_1275.npy
# Se encontró el archivo or_s_1276.npy
# Se encontró el archivo or_s_1277.npy
# Se encontró el archivo or_s_1278.npy
# Se encontró el archivo or_s_1279.npy
# Se encontró el archivo or_s_1280.npy
# Se encontró el archivo or_s_1281.npy
# Se encontró el archivo or_s_1282.npy
# Se encontró el archivo or_s_1283.npy
# Se encontró el archivo or_s_1284.npy
# Se encontró el archivo or_s_1285.npy
# Se encontró el archivo or_s_1286.npy
# Se encontró el archivo or_s_1287.npy
# Se encontró el archivo or_s_1288.npy
# Se encontró el archivo or_s_1289.npy
# Se encontró el archivo or_s_1290.npy
# Se encontró el archivo or_s_1291.npy
# Se encontró el archivo or_s_1292.npy
# Se encontró el archivo or_s_1293.npy
# Se encontró el archivo or_s_1294.npy
# Se encontró el archivo or_s_1295.npy
# Se encontró el archivo or_s_1296.npy
# Se encontró el archivo or_s_1297.npy
# Se encontró el archivo or_s_1298.npy
# Se encontró el archivo or_s_1299.npy
# Se encontró el archivo or_s_1300.npy
# Se encontró el archivo or_s_1301.npy
# Se encontró el archivo or_s_1302.npy
# Se encontró el archivo or_s_1303.npy
# Se encontró el archivo or_s_1304.npy
# Se encontró el archivo or_s_1305.npy
# Se encontró el archivo or_s_1306.npy
# Se encontró el archivo or_s_1307.npy
# Se encontró el archivo or_s_1308.npy
# Se encontró el archivo or_s_1309.npy
# Se encontró el archivo or_s_1310.npy
# Se encontró el archivo or_s_1311.npy
# Se encontró el archivo or_s_1312.npy
# Se encontró el archivo or_s_1313.npy
# Se encontró el archivo or_s_1314.npy
# Se encontró el archivo or_s_1315.npy
# Se encontró el archivo or_s_1316.npy
# Se encontró el archivo or_s_1317.npy
# Se encontró el archivo or_s_1318.npy
# Se encontró el archivo or_s_1319.npy
# Se encontró el archivo or_s_1320.npy
# Se encontró el archivo or_s_1321.npy
# Se encontró el archivo or_s_1322.npy
# Se encontró el archivo or_s_1323.npy
# Se encontró el archivo or_s_1324.npy
# Se encontró el archivo or_s_1325.npy
# Se encontró el archivo or_s_1326.npy
# ...
# Se encontró el archivo or_s_3169.npy
# Se encontró el archivo or_s_3170.npy
# Se encontró el archivo or_s_3171.npy
# Se encontró el archivo or_s_3172.npy
# Se encontró el archivo or_s_3173.npy
# Se encontró el archivo or_s_3174.npy
# Se encontró el archivo or_s_3175.npy
# Se encontró el archivo or_s_3176.npy
# Se encontró el archivo or_s_3177.npy
# Se encontró el archivo or_s_3178.npy
# Se encontró el archivo or_s_3179.npy
# Se encontró el archivo or_s_3180.npy
# Se encontró el archivo or_s_3181.npy
# Se encontró el archivo or_s_3182.npy
# Se encontró el archivo or_s_3183.npy
# Se encontró el archivo or_s_3184.npy
# Se encontró el archivo or_s_3185.npy
# Se encontró el archivo or_s_3186.npy
# Se encontró el archivo or_s_3187.npy
# Se encontró el archivo or_s_3188.npy
# Se encontró el archivo or_s_3189.npy
# Se encontró el archivo or_s_3190.npy
# Se encontró el archivo or_s_3191.npy
# Se encontró el archivo or_s_3192.npy
# Se encontró el archivo or_s_3193.npy
# Se encontró el archivo or_s_3194.npy
# Se encontró el archivo or_s_3195.npy
# Se encontró el archivo or_s_3196.npy
# Se encontró el archivo or_s_3197.npy
# Se encontró el archivo or_s_3198.npy
# Se encontró el archivo or_s_3199.npy
# Se encontró el archivo or_s_3200.npy
# Se encontró el archivo or_s_3201.npy
# Se encontró el archivo or_s_3202.npy
# Se encontró el archivo or_s_3203.npy
# Se encontró el archivo or_s_3204.npy
# Se encontró el archivo or_s_3205.npy
# Se encontró el archivo or_s_3206.npy
# Se encontró el archivo or_s_3207.npy
# Se encontró el archivo or_s_3208.npy
# Se encontró el archivo or_s_3209.npy
# Se encontró el archivo or_s_3210.npy
# Se encontró el archivo or_s_3211.npy
# Se encontró el archivo or_s_3212.npy
# Se encontró el archivo or_s_3213.npy
# Se encontró el archivo or_s_3214.npy
# Se encontró el archivo or_s_3215.npy
# Se encontró el archivo or_s_3216.npy
# Se encontró el archivo or_s_3217.npy
# Se encontró el archivo or_s_3218.npy
# Se encontró el archivo or_s_3219.npy
# Se encontró el archivo or_s_3220.npy
# Se encontró el archivo or_s_3221.npy
# Se encontró el archivo or_s_3222.npy
# Se encontró el archivo or_s_3223.npy
# Se encontró el archivo or_s_3224.npy
# Se encontró el archivo or_s_3225.npy
# Se encontró el archivo or_s_3226.npy
# Se encontró el archivo or_s_3227.npy
# Se encontró el archivo or_s_3228.npy
# Se encontró el archivo or_s_3229.npy
# Se encontró el archivo or_s_3230.npy
# Se encontró el archivo or_s_3231.npy
# Se encontró el archivo or_s_3232.npy
# Se encontró el archivo or_s_3233.npy
# Se encontró el archivo or_s_3234.npy
# Se encontró el archivo or_s_3235.npy
# Se encontró el archivo or_s_3236.npy
# Se encontró el archivo or_s_3237.npy
# Se encontró el archivo or_s_3238.npy
# Se encontró el archivo or_s_3239.npy
# Se encontró el archivo or_s_3240.npy
# Se encontró el archivo or_s_3241.npy
# Se encontró el archivo or_s_3242.npy
# Se encontró el archivo or_s_3243.npy
# Se encontró el archivo or_s_3244.npy
# Se encontró el archivo or_s_3245.npy
# Se encontró el archivo or_s_3246.npy
# Se encontró el archivo or_s_3247.npy
# Se encontró el archivo or_s_3248.npy
# Se encontró el archivo or_s_3249.npy
# Se encontró el archivo or_s_3250.npy
# Se encontró el archivo or_s_3251.npy
# Se encontró el archivo or_s_3252.npy
# Se encontró el archivo or_s_3253.npy
# Se encontró el archivo or_s_3254.npy
# Se encontró el archivo or_s_3255.npy
# Se encontró el archivo or_s_3256.npy
# Se encontró el archivo or_s_3257.npy
# Se encontró el archivo or_s_3258.npy
# Se encontró el archivo or_s_3259.npy
# Se encontró el archivo or_s_3260.npy
# Se encontró el archivo or_s_3261.npy
# Se encontró el archivo or_s_3262.npy
# Se encontró el archivo or_s_3263.npy
# Se encontró el archivo or_s_3264.npy
# Se encontró el archivo or_s_3265.npy
# Se encontró el archivo or_s_3266.npy
# Se encontró el archivo or_s_3267.npy
# Se encontró el archivo or_s_3268.npy
# Se encontró el archivo or_s_3269.npy
# Se encontró el archivo or_s_3270.npy
# Se encontró el archivo or_s_3271.npy
# Se encontró el archivo or_s_3272.npy
# Se encontró el archivo or_s_3273.npy
# Se encontró el archivo or_s_3274.npy
# Se encontró el archivo or_s_3275.npy
# Se encontró el archivo or_s_3276.npy
# Se encontró el archivo or_s_3277.npy
# Se encontró el archivo or_s_3278.npy
# Se encontró el archivo or_s_3279.npy
# Se encontró el archivo or_s_3280.npy
# Se encontró el archivo or_s_3281.npy
# Se encontró el archivo or_s_3282.npy
# Se encontró el archivo or_s_3283.npy
# Se encontró el archivo or_s_3284.npy
# Se encontró el archivo or_s_3285.npy
# Se encontró el archivo or_s_3286.npy
# Se encontró el archivo or_s_3287.npy
# Se encontró el archivo or_s_3288.npy
# Se encontró el archivo or_s_3289.npy
# Se encontró el archivo or_s_3290.npy
# Se encontró el archivo or_s_3291.npy
# Se encontró el archivo or_s_3292.npy
# Se encontró el archivo or_s_3293.npy
# Se encontró el archivo or_s_3294.npy
# Se encontró el archivo or_s_3295.npy
# Se encontró el archivo or_s_3296.npy
# Se encontró el archivo or_s_3297.npy
# Se encontró el archivo or_s_3298.npy
# Se encontró el archivo or_s_3299.npy
# Se encontró el archivo or_s_3300.npy
# Se encontró el archivo or_s_3301.npy
# Se encontró el archivo or_s_3302.npy
# Se encontró el archivo or_s_3303.npy
# Se encontró el archivo or_s_3304.npy
# Se encontró el archivo or_s_3305.npy
# Se encontró el archivo or_s_3306.npy
# Se encontró el archivo or_s_3307.npy
# Se encontró el archivo or_s_3308.npy
# Se encontró el archivo or_s_3309.npy
# Se encontró el archivo or_s_3310.npy
# Se encontró el archivo or_s_3311.npy
# Se encontró el archivo or_s_3312.npy
# Se encontró el archivo or_s_3313.npy
# Se encontró el archivo or_s_3314.npy
# Se encontró el archivo or_s_3315.npy
# Se encontró el archivo or_s_3316.npy
# Se encontró el archivo or_s_3317.npy
# Se encontró el archivo or_s_3318.npy
# Se encontró el archivo or_s_3319.npy
# Se encontró el archivo or_s_3320.npy
# Se encontró el archivo or_s_3321.npy
# Se encontró el archivo or_s_3322.npy
# Se encontró el archivo or_s_3323.npy
# Se encontró el archivo or_s_3324.npy
# Se encontró el archivo or_s_3325.npy
# Se encontró el archivo or_s_3326.npy
# Se encontró el archivo or_s_3327.npy
# Se encontró el archivo or_s_3328.npy
# Se encontró el archivo or_s_3329.npy
# Se encontró el archivo or_s_3330.npy
# Se encontró el archivo or_s_3331.npy
# Se encontró el archivo or_s_3332.npy
# Se encontró el archivo or_s_3333.npy
# Se encontró el archivo or_s_3334.npy
# Se encontró el archivo or_s_3335.npy
# Se encontró el archivo or_s_3336.npy
# Se encontró el archivo or_s_3337.npy
# Se encontró el archivo or_s_3338.npy
# Se encontró el archivo or_s_3339.npy
# Se encontró el archivo or_s_3340.npy
# Se encontró el archivo or_s_3341.npy
# Se encontró el archivo or_s_3342.npy
# Se encontró el archivo or_s_3343.npy
# Se encontró el archivo or_s_3344.npy
# Se encontró el archivo or_s_3345.npy
# Se encontró el archivo or_s_3346.npy
# Se encontró el archivo or_s_3347.npy
# Se encontró el archivo or_s_3348.npy
# Se encontró el archivo or_s_3349.npy
# Se encontró el archivo or_s_3350.npy
# Se encontró el archivo or_s_3351.npy
# Se encontró el archivo or_s_3352.npy
# Se encontró el archivo or_s_3353.npy
# Se encontró el archivo or_s_3354.npy
# Se encontró el archivo or_s_3355.npy
# Se encontró el archivo or_s_3356.npy
# Se encontró el archivo or_s_3357.npy
# Se encontró el archivo or_s_3358.npy
# Se encontró el archivo or_s_3359.npy
# Se encontró el archivo or_s_3360.npy
# Se encontró el archivo or_s_3361.npy
# Se encontró el archivo or_s_3362.npy
# Se encontró el archivo or_s_3363.npy
# Se encontró el archivo or_s_3364.npy
# Se encontró el archivo or_s_3365.npy
# Se encontró el archivo or_s_3366.npy
# Se encontró el archivo or_s_3367.npy
# Se encontró el archivo or_s_3368.npy
# Se encontró el archivo or_s_3369.npy
# Se encontró el archivo or_s_3370.npy
# Se encontró el archivo or_s_3371.npy
# Se encontró el archivo or_s_3372.npy
# Se encontró el archivo or_s_3373.npy
# Se encontró el archivo or_s_3374.npy
# Se encontró el archivo or_s_3375.npy
# Se encontró el archivo or_s_3376.npy
# Se encontró el archivo or_s_3377.npy
# Se encontró el archivo or_s_3378.npy
# Se encontró el archivo or_s_3379.npy
# Se encontró el archivo or_s_3380.npy
# Se encontró el archivo or_s_3381.npy
# Se encontró el archivo or_s_3382.npy
# Se encontró el archivo or_s_3383.npy
# Se encontró el archivo or_s_3384.npy
# Se encontró el archivo or_s_3385.npy
# Se encontró el archivo or_s_3386.npy
# Se encontró el archivo or_s_3387.npy
# Se encontró el archivo or_s_3388.npy
# Se encontró el archivo or_s_3389.npy
# Se encontró el archivo or_s_3390.npy
# Se encontró el archivo or_s_3391.npy
# Se encontró el archivo or_s_3392.npy
# Se encontró el archivo or_s_3393.npy
# Se encontró el archivo or_s_3394.npy
# Se encontró el archivo or_s_3395.npy
# Se encontró el archivo or_s_3396.npy
# Se encontró el archivo or_s_3397.npy
# Se encontró el archivo or_s_3398.npy
# Se encontró el archivo or_s_3399.npy
# Se encontró el archivo or_s_3400.npy
# Se encontró el archivo or_s_3401.npy
# Se encontró el archivo or_s_3402.npy
# Se encontró el archivo or_s_3403.npy
# Se encontró el archivo or_s_3404.npy
# Se encontró el archivo or_s_3405.npy
# Se encontró el archivo or_s_3406.npy
# Se encontró el archivo or_s_3407.npy
# Se encontró el archivo or_s_3408.npy
# Se encontró el archivo or_s_3409.npy
# Se encontró el archivo or_s_3410.npy
# Se encontró el archivo or_s_3411.npy
# Se encontró el archivo or_s_3412.npy
# Se encontró el archivo or_s_3413.npy
# Se encontró el archivo or_s_3414.npy
# Se encontró el archivo or_s_3415.npy
# Se encontró el archivo or_s_3416.npy
# Se encontró el archivo or_s_3417.npy
# Se encontró el archivo or_s_3418.npy
# Se encontró el archivo or_s_3419.npy
# Se encontró el archivo or_s_3420.npy
# Se encontró el archivo or_s_3421.npy
# Se encontró el archivo or_s_3422.npy
# Se encontró el archivo or_s_3423.npy
# Se encontró el archivo or_s_3424.npy
# Se encontró el archivo or_s_3425.npy
# Se encontró el archivo or_s_3426.npy
# Se encontró el archivo or_s_3427.npy
# Se encontró el archivo or_s_3428.npy
# Se encontró el archivo or_s_3429.npy
# Se encontró el archivo or_s_3430.npy
# Se encontró el archivo or_s_3431.npy
# Se encontró el archivo or_s_3432.npy
# Se encontró el archivo or_s_3433.npy
# Se encontró el archivo or_s_3434.npy
# Se encontró el archivo or_s_3435.npy
# Se encontró el archivo or_s_3436.npy
# Se encontró el archivo or_s_3437.npy
# Se encontró el archivo or_s_3438.npy
# Se encontró el archivo or_s_3439.npy
# Se encontró el archivo or_s_3440.npy
# Se encontró el archivo or_s_3441.npy
# Se encontró el archivo or_s_3442.npy
# Se encontró el archivo or_s_3443.npy
# Se encontró el archivo or_s_3444.npy
# Se encontró el archivo or_s_3445.npy
# Se encontró el archivo or_s_3446.npy
# Se encontró el archivo or_s_3447.npy
# Se encontró el archivo or_s_3448.npy
# Se encontró el archivo or_s_3449.npy
# Se encontró el archivo or_s_3450.npy
# Se encontró el archivo or_s_3451.npy
# Se encontró el archivo or_s_3452.npy
# Se encontró el archivo or_s_3453.npy
# Se encontró el archivo or_s_3454.npy
# Se encontró el archivo or_s_3455.npy
# Se encontró el archivo or_s_3456.npy
# Se encontró el archivo or_s_3457.npy
# Se encontró el archivo or_s_3458.npy
# Se encontró el archivo or_s_3459.npy
# Se encontró el archivo or_s_3460.npy
# Se encontró el archivo or_s_3461.npy
# Se encontró el archivo or_s_3462.npy
# Se encontró el archivo or_s_3463.npy
# Se encontró el archivo or_s_3464.npy
# Se encontró el archivo or_s_3465.npy
# Se encontró el archivo or_s_3466.npy
# Se encontró el archivo or_s_3467.npy
# Se encontró el archivo or_s_3468.npy
# Se encontró el archivo or_s_3469.npy
# Se encontró el archivo or_s_3470.npy
# Se encontró el archivo or_s_3471.npy
# Se encontró el archivo or_s_3472.npy
# Se encontró el archivo or_s_3473.npy
# Se encontró el archivo or_s_3474.npy
# Se encontró el archivo or_s_3475.npy
# Se encontró el archivo or_s_3476.npy
# Se encontró el archivo or_s_3477.npy
# Se encontró el archivo or_s_3478.npy
# Se encontró el archivo or_s_3479.npy
# Se encontró el archivo or_s_3480.npy
# Se encontró el archivo or_s_3481.npy
# Se encontró el archivo or_s_3482.npy
# Se encontró el archivo or_s_3483.npy
# Se encontró el archivo or_s_3484.npy
# Se encontró el archivo or_s_3485.npy
# Se encontró el archivo or_s_3486.npy
# Se encontró el archivo or_s_3487.npy
# Se encontró el archivo or_s_3488.npy
# Se encontró el archivo or_s_3489.npy
# Se encontró el archivo or_s_3490.npy
# Se encontró el archivo or_s_3491.npy
# Se encontró el archivo or_s_3492.npy
# Se encontró el archivo or_s_3493.npy
# Se encontró el archivo or_s_3494.npy
# Se encontró el archivo or_s_3495.npy
# Se encontró el archivo or_s_3496.npy
# Se encontró el archivo or_s_3497.npy
# Se encontró el archivo or_s_3498.npy
# Se encontró el archivo or_s_3499.npy
# Se encontró el archivo or_s_3500.npy
# Se encontró el archivo or_s_3501.npy
# Se encontró el archivo or_s_3502.npy
# Se encontró el archivo or_s_3503.npy
# Se encontró el archivo or_s_3504.npy
# Se encontró el archivo or_s_3505.npy
# Se encontró el archivo or_s_3506.npy
# Se encontró el archivo or_s_3507.npy
# Se encontró el archivo or_s_3508.npy
# Se encontró el archivo or_s_3509.npy
# Se encontró el archivo or_s_3510.npy
# Se encontró el archivo or_s_3511.npy
# Se encontró el archivo or_s_3512.npy
# Se encontró el archivo or_s_3513.npy
# Se encontró el archivo or_s_3514.npy
# Se encontró el archivo or_s_3515.npy
# Se encontró el archivo or_s_3516.npy
# Se encontró el archivo or_s_3517.npy
# Se encontró el archivo or_s_3518.npy
# Se encontró el archivo or_s_3519.npy
# Se encontró el archivo or_s_3520.npy
# Se encontró el archivo or_s_3521.npy
# Se encontró el archivo or_s_3522.npy
# Se encontró el archivo or_s_3523.npy
# Se encontró el archivo or_s_3524.npy
# Se encontró el archivo or_s_3525.npy
# Se encontró el archivo or_s_3526.npy
# Se encontró el archivo or_s_3527.npy
# Se encontró el archivo or_s_3528.npy
# Se encontró el archivo or_s_3529.npy
# Se encontró el archivo or_s_3530.npy
# Se encontró el archivo or_s_3531.npy
# Se encontró el archivo or_s_3532.npy
# Se encontró el archivo or_s_3533.npy
# Se encontró el archivo or_s_3534.npy
# Se encontró el archivo or_s_3535.npy
# Se encontró el archivo or_s_3536.npy
# Se encontró el archivo or_s_3537.npy
# Se encontró el archivo or_s_3538.npy
# Se encontró el archivo or_s_3539.npy
# Se encontró el archivo or_s_3540.npy
# Se encontró el archivo or_s_3541.npy
# Se encontró el archivo or_s_3542.npy
# Se encontró el archivo or_s_3543.npy
# Se encontró el archivo or_s_3544.npy
# Se encontró el archivo or_s_3545.npy
# Se encontró el archivo or_s_3546.npy
# Se encontró el archivo or_s_3547.npy
# Se encontró el archivo or_s_3548.npy
# Se encontró el archivo or_s_3549.npy
# Se encontró el archivo or_s_3550.npy
# Se encontró el archivo or_s_3551.npy
# Se encontró el archivo or_s_3552.npy
# Se encontró el archivo or_s_3553.npy
# Se encontró el archivo or_s_3554.npy
# Se encontró el archivo or_s_3555.npy
# Se encontró el archivo or_s_3556.npy
# Se encontró el archivo or_s_3557.npy
# Se encontró el archivo or_s_3558.npy
# Se encontró el archivo or_s_3559.npy
# Se encontró el archivo or_s_3560.npy
# Se encontró el archivo or_s_3561.npy
# Se encontró el archivo or_s_3562.npy
# Se encontró el archivo or_s_3563.npy
# Se encontró el archivo or_s_3564.npy
# Se encontró el archivo or_s_3565.npy
# Se encontró el archivo or_s_3566.npy
# Se encontró el archivo or_s_3567.npy
# Se encontró el archivo or_s_3568.npy
# Se encontró el archivo or_s_3569.npy
# Se encontró el archivo or_s_3570.npy
# Se encontró el archivo or_s_3571.npy
# Se encontró el archivo or_s_3572.npy
# Se encontró el archivo or_s_3573.npy
# Se encontró el archivo or_s_3574.npy
# Se encontró el archivo or_s_3575.npy
# Se encontró el archivo or_s_3576.npy
# Se encontró el archivo or_s_3577.npy
# Se encontró el archivo or_s_3578.npy
# Se encontró el archivo or_s_3579.npy
# Se encontró el archivo or_s_3580.npy
# Se encontró el archivo or_s_3581.npy
# Se encontró el archivo or_s_3582.npy
# Se encontró el archivo or_s_3583.npy
# Se encontró el archivo or_s_3584.npy
# Se encontró el archivo or_s_3585.npy
# Se encontró el archivo or_s_3586.npy
# Se encontró el archivo or_s_3587.npy
# Se encontró el archivo or_s_3588.npy
# Se encontró el archivo or_s_3589.npy
# Se encontró el archivo or_s_3590.npy
# Se encontró el archivo or_s_3591.npy
# Se encontró el archivo or_s_3592.npy
# Se encontró el archivo or_s_3593.npy
# Se encontró el archivo or_s_3594.npy
# Se encontró el archivo or_s_3595.npy
# Se encontró el archivo or_s_3596.npy
# Se encontró el archivo or_s_3597.npy
# Se encontró el archivo or_s_3598.npy
# Se encontró el archivo or_s_3599.npy
# Se encontró el archivo or_s_3600.npy

# %% [markdown]
# Al igual que en *'Signal_Extractor.ipynb'* se genera aleatoriamente una represetación de una señal para saber si ha funcionado.

# %%
# Generar un número aleatorio entre 1 y 3600 para seleccionar el archivo
import random

archivo_numero = random.randint(1, 3600)
archivo_path = os.path.join(os.getcwd(), 'sag_signals', f'sg_s_{archivo_numero}.npy')

# Cargar el archivo completo
signal_data = np.load(archivo_path)

# Graficar todos los datos de la señal
plt.figure(figsize=(12, 6))
plt.plot(signal_data, color='b', linestyle='-', linewidth=0.8, label='Amplitud en el tiempo')
plt.title(f"Representación completa de la señal - Archivo or_s_{archivo_numero}.npy")
plt.xlabel("Muestras")
plt.ylabel("Amplitud")
plt.legend()
plt.grid(True)
plt.show()
